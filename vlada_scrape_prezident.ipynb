# %%
import os
import re
import time
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import json

BASE_URL = "https://www.odok.gov.cz"
LISTING_URL = BASE_URL + "/portal/zvlady/jednani/{year}"
URLS = "links.json"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/124.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    "Accept-Language": "cs,en-US;q=0.9,en;q=0.8",
    "Referer": "https://www.odok.gov.cz/",
    "Connection": "keep-alive",
}


def sanitize_filename(name):
    # Replace any character that is not a word character (a-zA-Z0-9_), dash, underscore, dot, or space
    # with an underscore. This helps avoid issues with illegal characters in filenames.
    return re.sub(r"[^\w\-_\. ]", "_", name)

# %% [markdown]
# ## Scrape links to "vladne ujednani"

# %% [markdown]
# #### Scrape 2009-2025

# %%
def get_meeting_links(year):
    # Construct the URL for the given year using a template string
    url = LISTING_URL.format(year=year)

    # Send an HTTP GET request to retrieve the webpage for the specified year
    res = requests.get(url, headers=HEADERS)

    # If the request fails, log the status and return an empty list
    if res.status_code != 200:
        print(f"Failed to retrieve data for year {year}: {res.status_code}")
        return []

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(res.content, "html.parser")
    links = []

    # Select all anchor tags that link to meeting detail pages
    for a in soup.select("a[href*='/portal/zvlady/jednani-detail/']"):
        href = a["href"]
        # Avoid duplicates and construct the full URL
        if href not in links:
            links.append(BASE_URL + href)

    # Return a list of unique meeting URLs for the given year
    return links

def scrape_all(start_year=2009, end_year=2025):
    # Dictionary to store meeting links per year
    links = dict()
    num_of_meetings = 0

    # Iterate over each year in the specified range
    for year in range(start_year, end_year + 1):
        print(f"\nProcessing year: {year}")
        meetings = get_meeting_links(year)

        # Store the links found for this year
        links[year] = meetings
        print(len(meetings), "meetings found")

        # Keep a running total of all meetings
        num_of_meetings += len(meetings)
    
    # Return a dictionary of all links and the total count
    return links, num_of_meetings

# %%
links, num_of_meetings = scrape_all()
print(f"\nTotal meetings found: {num_of_meetings}")

# %%
with open(URLS, "w", encoding="utf-8") as f:
    json.dump(links, f, ensure_ascii=False, indent=2)

# %% [markdown]
# #### Get statistics

# %%
def extract_usneseni_from_listing(year):
    # Construct the listing URL for the given year
    url = LISTING_URL.format(year=year)
    
    # Perform HTTP GET request to retrieve the HTML content
    res = requests.get(url, headers=HEADERS)
    if res.status_code != 200:
        print(f"❌ Failed to load {url}")
        return {}

    # Parse the HTML response
    soup = BeautifulSoup(res.content, "html.parser")
    year_data = {}

    # Select all anchor tags inside the blocks (they contain the date)
    for a in soup.select("div.mx-2 a"):
        # Extract text and strip whitespace
        date_text = a.get_text(strip=True)

        # Look for a date in YYYY-MM-DD format
        date_match = re.match(r"\d{4}-\d{2}-\d{2}", date_text)
        if not date_match:
            continue

        # Extract standardized date string
        date_str = date_match.group(0)

        # Look for the nearest sibling that contains "Usnesení č."
        parent = a.find_parent("div")
        next_div = parent.find_next_sibling("div") if parent else None

        if next_div:
            # Extract the full text and search for the range pattern "Usnesení č. 1–14"
            usneseni_text = next_div.get_text(strip=True)
            match = re.search(r"Usnesení č\.\s*(\d+)[–-](\d+)", usneseni_text)
            # If match is found, compute the total number of resolutions for that date
            if match:
                start, end = int(match.group(1)), int(match.group(2))
                count = end - start + 1
                year_data[date_str] = count
                print(f"🗓 {date_str}: {count} usnesení")
    
    # Return dictionary mapping dates to number of resolutions
    return year_data


def extract_all_usneseni_counts(start_year=2009, end_year=2025):
    """
    Extracts resolution (usnesení) counts for each year in the specified range.
    For every year, it invokes extract_usneseni_from_listing(year) and aggregates the results.

    Returns:
        dict: Nested dictionary structured as {year: {date: count_of_resolutions}}
    """
    all_data = {}
    for year in range(start_year, end_year + 1):
        print(f"\n📅 Year: {year}")
        # Extract data for the given year and store it using the year as string key
        all_data[str(year)] = extract_usneseni_from_listing(year)
    return all_data


def save_json(data, filename="usneseni_by_year.json"):
    """
    Saves the given data dictionary to a JSON file.

    Args:
        data (dict): Data structure containing resolution counts by year and date
        filename (str): Output filename for the resulting JSON file
    """
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)
    print(f"\n✅ Saved to {filename}")
    
# Execute extraction and persist results to a file
data = extract_all_usneseni_counts()
save_json(data)
# Out:
# 📅 Year: 2009
# 🗓 2009-12-21: 19 usnesení
# 🗓 2009-12-14: 21 usnesení
# 🗓 2009-12-07: 4 usnesení
# 🗓 2009-12-02: 63 usnesení
# 🗓 2009-11-30: 34 usnesení
# 🗓 2009-11-23: 1 usnesení
# 🗓 2009-11-19: 29 usnesení
# 🗓 2009-11-16: 1 usnesení
# 🗓 2009-11-11: 1 usnesení
# 🗓 2009-11-10: 14 usnesení
# 🗓 2009-11-09: 17 usnesení
# 🗓 2009-11-02: 2 usnesení
# 🗓 2009-10-28: 21 usnesení
# 🗓 2009-10-26: 31 usnesení
# 🗓 2009-10-19: 2 usnesení
# 🗓 2009-10-15: 25 usnesení
# 🗓 2009-10-12: 24 usnesení
# 🗓 2009-10-05: 14 usnesení
# 🗓 2009-09-29: 19 usnesení
# 🗓 2009-09-21: 37 usnesení
# 🗓 2009-09-16: 1 usnesení
# 🗓 2009-09-09: 40 usnesení
# 🗓 2009-09-03: 26 usnesení
# 🗓 2009-08-31: 55 usnesení
# 🗓 2009-08-26: 1 usnesení
# 🗓 2009-08-21: 43 usnesení
# 🗓 2009-08-17: 40 usnesení
# 🗓 2009-07-27: 41 usnesení
# 🗓 2009-07-20: 1 usnesení
# 🗓 2009-07-14: 57 usnesení
# 🗓 2009-07-13: 36 usnesení
# 🗓 2009-06-29: 1 usnesení
# 🗓 2009-06-25: 43 usnesení
# 🗓 2009-06-22: 1 usnesení
# 🗓 2009-06-17: 34 usnesení
# 🗓 2009-06-15: 41 usnesení
# 🗓 2009-06-08: 34 usnesení
# 🗓 2009-06-01: 35 usnesení
# 🗓 2009-05-25: 7 usnesení
# 🗓 2009-05-18: 4 usnesení
# 🗓 2009-05-08: 13 usnesení
# 🗓 2009-05-06: 59 usnesení
# 🗓 2009-05-04: 52 usnesení
# 🗓 2009-04-27: 65 usnesení
# 🗓 2009-04-20: 1 usnesení
# 🗓 2009-04-14: 34 usnesení
# 🗓 2009-04-06: 38 usnesení
# 🗓 2009-03-30: 1 usnesení
# 🗓 2009-03-26: 47 usnesení
# 🗓 2009-03-23: 2 usnesení
# 🗓 2009-03-17: 33 usnesení
# 🗓 2009-03-16: 25 usnesení
# 🗓 2009-03-09: 2 usnesení
# 🗓 2009-03-05: 43 usnesení
# 🗓 2009-03-02: 13 usnesení
# 🗓 2009-02-20: 25 usnesení
# 🗓 2009-02-16: 18 usnesení
# 🗓 2009-02-09: 37 usnesení
# 🗓 2009-02-02: 22 usnesení
# 🗓 2009-01-26: 37 usnesení
# 🗓 2009-01-19: 28 usnesení
# 🗓 2009-01-12: 38 usnesení
#
# 📅 Year: 2010
# 🗓 2010-12-22: 21 usnesení
# 🗓 2010-12-14: 24 usnesení
# 🗓 2010-12-07: 24 usnesení
# 🗓 2010-12-01: 22 usnesení
# 🗓 2010-11-24: 13 usnesení
# 🗓 2010-11-16: 21 usnesení
# 🗓 2010-11-10: 20 usnesení
# 🗓 2010-11-03: 13 usnesení
# 🗓 2010-10-27: 2 usnesení
# 🗓 2010-10-26: 24 usnesení
# 🗓 2010-10-20: 9 usnesení
# 🗓 2010-10-13: 20 usnesení
# 🗓 2010-10-06: 22 usnesení
# 🗓 2010-09-29: 16 usnesení
# 🗓 2010-09-22: 22 usnesení
# 🗓 2010-09-15: 7 usnesení
# 🗓 2010-09-08: 18 usnesení
# 🗓 2010-09-01: 22 usnesení
# 🗓 2010-08-25: 13 usnesení
# 🗓 2010-08-18: 22 usnesení
# 🗓 2010-08-11: 3 usnesení
# 🗓 2010-08-09: 7 usnesení
# 🗓 2010-08-04: 6 usnesení
# 🗓 2010-07-28: 8 usnesení
# 🗓 2010-07-21: 2 usnesení
# 🗓 2010-07-13: 20 usnesení
# 🗓 2010-07-12: 21 usnesení
# 🗓 2010-06-28: 1 usnesení
# 🗓 2010-06-25: 13 usnesení
# 🗓 2010-06-21: 26 usnesení
# 🗓 2010-06-14: 22 usnesení
# 🗓 2010-06-07: 17 usnesení
# 🗓 2010-05-31: 54 usnesení
# 🗓 2010-05-24: 1 usnesení
# 🗓 2010-05-17: 26 usnesení
# 🗓 2010-05-10: 18 usnesení
# 🗓 2010-05-03: 11 usnesení
# 🗓 2010-04-27: 28 usnesení
# 🗓 2010-04-19: 1 usnesení
# 🗓 2010-04-13: 22 usnesení
# 🗓 2010-04-09: 21 usnesení
# 🗓 2010-03-29: 19 usnesení
# 🗓 2010-03-22: 14 usnesení
# 🗓 2010-03-15: 14 usnesení
# 🗓 2010-03-08: 17 usnesení
# 🗓 2010-03-01: 1 usnesení
# 🗓 2010-02-25: 41 usnesení
# 🗓 2010-02-22: 29 usnesení
# 🗓 2010-02-08: 15 usnesení
# 🗓 2010-02-01: 10 usnesení
# 🗓 2010-01-25: 21 usnesení
# 🗓 2010-01-18: 24 usnesení
# 🗓 2010-01-11: 29 usnesení
#
# 📅 Year: 2011
# 🗓 2011-12-21: 2 usnesení
# 🗓 2011-12-19: 28 usnesení
# 🗓 2011-12-14: 25 usnesení
# 🗓 2011-12-07: 1 usnesení
# 🗓 2011-12-02: 15 usnesení
# 🗓 2011-11-30: 25 usnesení
# 🗓 2011-11-23: 20 usnesení
# 🗓 2011-11-16: 23 usnesení
# 🗓 2011-11-09: 18 usnesení
# 🗓 2011-11-02: 10 usnesení
# 🗓 2011-10-25: 22 usnesení
# 🗓 2011-10-19: 16 usnesení
# 🗓 2011-10-12: 17 usnesení
# 🗓 2011-10-05: 14 usnesení
# 🗓 2011-09-27: 21 usnesení
# 🗓 2011-09-21: 17 usnesení
# 🗓 2011-09-14: 14 usnesení
# 🗓 2011-09-08: 15 usnesení
# 🗓 2011-08-31: 18 usnesení
# 🗓 2011-08-24: 14 usnesení
# 🗓 2011-08-17: 23 usnesení
# 🗓 2011-08-10: 46 usnesení
# 🗓 2011-07-20: 28 usnesení
# 🗓 2011-07-13: 26 usnesení
# 🗓 2011-06-29: 23 usnesení
# 🗓 2011-06-22: 23 usnesení
# 🗓 2011-06-15: 1 usnesení
# 🗓 2011-06-11: 28 usnesení
# 🗓 2011-06-08: 18 usnesení
# 🗓 2011-06-02: 11 usnesení
# 🗓 2011-05-25: 30 usnesení
# 🗓 2011-05-18: 21 usnesení
# 🗓 2011-05-11: 16 usnesení
# 🗓 2011-05-04: 21 usnesení
# 🗓 2011-04-27: 21 usnesení
# 🗓 2011-04-20: 26 usnesení
# 🗓 2011-04-13: 21 usnesení
# 🗓 2011-04-06: 10 usnesení
# 🗓 2011-03-30: 16 usnesení
# 🗓 2011-03-23: 19 usnesení
# 🗓 2011-03-17: 19 usnesení
# 🗓 2011-03-09: 17 usnesení
# 🗓 2011-03-02: 17 usnesení
# 🗓 2011-02-23: 19 usnesení
# 🗓 2011-02-16: 21 usnesení
# 🗓 2011-02-09: 10 usnesení
# 🗓 2011-02-02: 16 usnesení
# 🗓 2011-01-26: 31 usnesení
# 🗓 2011-01-19: 12 usnesení
# 🗓 2011-01-12: 23 usnesení
#
# 📅 Year: 2012
# 🗓 2012-12-19: 2 usnesení
# 🗓 2012-12-14: 22 usnesení
# 🗓 2012-12-12: 28 usnesení
# 🗓 2012-12-05: 23 usnesení
# 🗓 2012-11-28: 13 usnesení
# 🗓 2012-11-21: 29 usnesení
# 🗓 2012-11-14: 17 usnesení
# 🗓 2012-11-05: 12 usnesení
# 🗓 2012-10-31: 13 usnesení
# 🗓 2012-10-24: 16 usnesení
# 🗓 2012-10-17: 24 usnesení
# 🗓 2012-10-10: 27 usnesení
# 🗓 2012-10-03: 17 usnesení
# 🗓 2012-09-26: 1 usnesení
# 🗓 2012-09-20: 13 usnesení
# 🗓 2012-09-19: 23 usnesení
# 🗓 2012-09-12: 11 usnesení
# 🗓 2012-09-06: 24 usnesení
# 🗓 2012-08-29: 19 usnesení
# 🗓 2012-08-22: 12 usnesení
# 🗓 2012-08-15: 25 usnesení
# 🗓 2012-07-25: 32 usnesení
# 🗓 2012-07-19: 18 usnesení
# 🗓 2012-07-11: 32 usnesení
# 🗓 2012-07-04: 26 usnesení
# 🗓 2012-06-26: 25 usnesení
# 🗓 2012-06-19: 26 usnesení
# 🗓 2012-06-13: 9 usnesení
# 🗓 2012-06-06: 20 usnesení
# 🗓 2012-05-30: 16 usnesení
# 🗓 2012-05-23: 18 usnesení
# 🗓 2012-05-16: 16 usnesení
# 🗓 2012-05-09: 17 usnesení
# 🗓 2012-05-02: 16 usnesení
# 🗓 2012-04-25: 18 usnesení
# 🗓 2012-04-18: 32 usnesení
# 🗓 2012-04-11: 21 usnesení
# 🗓 2012-04-04: 24 usnesení
# 🗓 2012-03-28: 21 usnesení
# 🗓 2012-03-21: 30 usnesení
# 🗓 2012-03-14: 14 usnesení
# 🗓 2012-03-07: 15 usnesení
# 🗓 2012-02-29: 15 usnesení
# 🗓 2012-02-22: 22 usnesení
# 🗓 2012-02-15: 10 usnesení
# 🗓 2012-02-08: 8 usnesení
# 🗓 2012-02-01: 10 usnesení
# 🗓 2012-01-25: 14 usnesení
# 🗓 2012-01-18: 19 usnesení
# 🗓 2012-01-11: 20 usnesení
#
# 📅 Year: 2013
# 🗓 2013-12-18: 23 usnesení
# 🗓 2013-12-11: 16 usnesení
# 🗓 2013-12-04: 29 usnesení
# 🗓 2013-11-27: 22 usnesení
# 🗓 2013-11-20: 14 usnesení
# 🗓 2013-11-13: 15 usnesení
# 🗓 2013-11-06: 22 usnesení
# 🗓 2013-10-30: 20 usnesení
# 🗓 2013-10-23: 30 usnesení
# 🗓 2013-10-09: 11 usnesení
# 🗓 2013-10-02: 22 usnesení
# 🗓 2013-09-25: 25 usnesení
# 🗓 2013-09-18: 20 usnesení
# 🗓 2013-09-11: 11 usnesení
# 🗓 2013-09-04: 9 usnesení
# 🗓 2013-08-28: 22 usnesení
# 🗓 2013-08-21: 24 usnesení
# 🗓 2013-08-14: 34 usnesení
# 🗓 2013-08-07: 1 usnesení
# 🗓 2013-08-02: 26 usnesení
# 🗓 2013-07-31: 1 usnesení
# 🗓 2013-07-25: 11 usnesení
# 🗓 2013-07-19: 7 usnesení
# 🗓 2013-07-16: 1 usnesení
# 🗓 2013-07-10: 22 usnesení
# 🗓 2013-07-03: 21 usnesení
# 🗓 2013-06-26: 24 usnesení
# 🗓 2013-06-19: 37 usnesení
# 🗓 2013-06-12: 21 usnesení
# 🗓 2013-06-05: 3 usnesení
# 🗓 2013-06-02: 20 usnesení
# 🗓 2013-05-29: 18 usnesení
# 🗓 2013-05-22: 38 usnesení
# 🗓 2013-05-15: 28 usnesení
# 🗓 2013-05-02: 23 usnesení
# 🗓 2013-04-24: 21 usnesení
# 🗓 2013-04-17: 19 usnesení
# 🗓 2013-04-10: 16 usnesení
# 🗓 2013-04-03: 8 usnesení
# 🗓 2013-03-27: 23 usnesení
# 🗓 2013-03-20: 23 usnesení
# 🗓 2013-03-13: 19 usnesení
# 🗓 2013-03-06: 27 usnesení
# 🗓 2013-02-27: 13 usnesení
# 🗓 2013-02-20: 13 usnesení
# 🗓 2013-02-13: 16 usnesení
# 🗓 2013-02-06: 15 usnesení
# 🗓 2013-01-30: 18 usnesení
# 🗓 2013-01-23: 18 usnesení
# 🗓 2013-01-16: 31 usnesení
#
# 📅 Year: 2014
# 🗓 2014-12-22: 31 usnesení
# 🗓 2014-12-15: 41 usnesení
# 🗓 2014-12-08: 19 usnesení
# 🗓 2014-12-01: 32 usnesení
# 🗓 2014-11-24: 44 usnesení
# 🗓 2014-11-12: 23 usnesení
# 🗓 2014-11-03: 24 usnesení
# 🗓 2014-10-27: 14 usnesení
# 🗓 2014-10-20: 19 usnesení
# 🗓 2014-10-15: 21 usnesení
# 🗓 2014-10-08: 27 usnesení
# 🗓 2014-10-01: 14 usnesení
# 🗓 2014-09-22: 25 usnesení
# 🗓 2014-09-15: 15 usnesení
# 🗓 2014-09-10: 32 usnesení
# 🗓 2014-09-03: 27 usnesení
# 🗓 2014-08-27: 27 usnesení
# 🗓 2014-08-06: 20 usnesení
# 🗓 2014-07-30: 2 usnesení
# 🗓 2014-07-24: 18 usnesení
# 🗓 2014-07-21: 42 usnesení
# 🗓 2014-07-14: 37 usnesení
# 🗓 2014-07-09: 26 usnesení
# 🗓 2014-07-02: 33 usnesení
# 🗓 2014-06-25: 28 usnesení
# 🗓 2014-06-16: 4 usnesení
# 🗓 2014-06-09: 23 usnesení
# 🗓 2014-06-04: 25 usnesení
# 🗓 2014-05-28: 26 usnesení
# 🗓 2014-05-21: 20 usnesení
# 🗓 2014-05-12: 18 usnesení
# 🗓 2014-05-05: 29 usnesení
# 🗓 2014-04-28: 19 usnesení
# 🗓 2014-04-23: 26 usnesení
# 🗓 2014-04-16: 27 usnesení
# 🗓 2014-04-09: 24 usnesení
# 🗓 2014-04-02: 15 usnesení
# 🗓 2014-03-24: 11 usnesení
# 🗓 2014-03-17: 20 usnesení
# 🗓 2014-03-12: 21 usnesení
# 🗓 2014-03-05: 13 usnesení
# 🗓 2014-02-26: 18 usnesení
# 🗓 2014-02-19: 2 usnesení
# 🗓 2014-02-12: 5 usnesení
# 🗓 2014-02-10: 8 usnesení
# 🗓 2014-02-03: 7 usnesení
# 🗓 2014-01-29: 21 usnesení
# 🗓 2014-01-22: 15 usnesení
# 🗓 2014-01-15: 23 usnesení
# 🗓 2014-01-08: 16 usnesení
#
# 📅 Year: 2015
# 🗓 2015-12-21: 35 usnesení
# 🗓 2015-12-14: 31 usnesení
# 🗓 2015-12-07: 15 usnesení
# 🗓 2015-12-02: 1 usnesení
# 🗓 2015-11-28: 44 usnesení
# 🗓 2015-11-20: 22 usnesení
# 🗓 2015-11-09: 24 usnesení
# 🗓 2015-11-02: 35 usnesení
# 🗓 2015-10-26: 22 usnesení
# 🗓 2015-10-19: 28 usnesení
# 🗓 2015-10-12: 21 usnesení
# 🗓 2015-10-05: 10 usnesení
# 🗓 2015-09-30: 22 usnesení
# 🗓 2015-09-23: 9 usnesení
# 🗓 2015-09-14: 8 usnesení
# 🗓 2015-09-09: 15 usnesení
# 🗓 2015-08-31: 28 usnesení
# 🗓 2015-08-26: 40 usnesení
# 🗓 2015-08-20: 61 usnesení
# 🗓 2015-07-29: 8 usnesení
# 🗓 2015-07-22: 19 usnesení
# 🗓 2015-07-13: 21 usnesení
# 🗓 2015-07-08: 23 usnesení
# 🗓 2015-07-01: 30 usnesení
# 🗓 2015-06-24: 24 usnesení
# 🗓 2015-06-15: 19 usnesení
# 🗓 2015-06-08: 28 usnesení
# 🗓 2015-06-03: 38 usnesení
# 🗓 2015-05-25: 14 usnesení
# 🗓 2015-05-18: 14 usnesení
# 🗓 2015-05-13: 24 usnesení
# 🗓 2015-05-06: 1 usnesení
# 🗓 2015-04-29: 18 usnesení
# 🗓 2015-04-27: 18 usnesení
# 🗓 2015-04-22: 23 usnesení
# 🗓 2015-04-15: 27 usnesení
# 🗓 2015-04-08: 21 usnesení
# 🗓 2015-03-30: 11 usnesení
# 🗓 2015-03-25: 22 usnesení
# 🗓 2015-03-16: 14 usnesení
# 🗓 2015-03-09: 18 usnesení
# 🗓 2015-03-04: 33 usnesení
# 🗓 2015-02-23: 14 usnesení
# 🗓 2015-02-16: 16 usnesení
# 🗓 2015-02-09: 15 usnesení
# 🗓 2015-02-04: 18 usnesení
# 🗓 2015-01-28: 16 usnesení
# 🗓 2015-01-19: 18 usnesení
# 🗓 2015-01-14: 16 usnesení
#
# 📅 Year: 2016
# 🗓 2016-12-19: 44 usnesení
# 🗓 2016-12-14: 30 usnesení
# 🗓 2016-12-05: 29 usnesení
# 🗓 2016-11-28: 27 usnesení
# 🗓 2016-11-23: 16 usnesení
# 🗓 2016-11-16: 25 usnesení
# 🗓 2016-11-07: 24 usnesení
# 🗓 2016-11-02: 24 usnesení
# 🗓 2016-10-24: 14 usnesení
# 🗓 2016-10-17: 26 usnesení
# 🗓 2016-10-12: 23 usnesení
# 🗓 2016-10-05: 40 usnesení
# 🗓 2016-09-21: 16 usnesení
# 🗓 2016-09-12: 14 usnesení
# 🗓 2016-09-05: 29 usnesení
# 🗓 2016-08-31: 53 usnesení
# 🗓 2016-08-24: 55 usnesení
# 🗓 2016-07-27: 18 usnesení
# 🗓 2016-07-20: 13 usnesení
# 🗓 2016-07-11: 19 usnesení
# 🗓 2016-07-07: 32 usnesení
# 🗓 2016-06-27: 22 usnesení
# 🗓 2016-06-22: 23 usnesení
# 🗓 2016-06-15: 32 usnesení
# 🗓 2016-06-08: 26 usnesení
# 🗓 2016-05-30: 16 usnesení
# 🗓 2016-05-23: 23 usnesení
# 🗓 2016-05-18: 31 usnesení
# 🗓 2016-05-11: 21 usnesení
# 🗓 2016-05-02: 28 usnesení
# 🗓 2016-04-27: 20 usnesení
# 🗓 2016-04-18: 26 usnesení
# 🗓 2016-04-11: 15 usnesení
# 🗓 2016-04-07: 30 usnesení
# 🗓 2016-03-30: 2 usnesení
# 🗓 2016-03-22: 22 usnesení
# 🗓 2016-03-21: 31 usnesení
# 🗓 2016-03-16: 27 usnesení
# 🗓 2016-03-09: 14 usnesení
# 🗓 2016-02-29: 18 usnesení
# 🗓 2016-02-24: 27 usnesení
# 🗓 2016-02-17: 23 usnesení
# 🗓 2016-02-08: 28 usnesení
# 🗓 2016-02-03: 26 usnesení
# 🗓 2016-01-25: 25 usnesení
# 🗓 2016-01-18: 19 usnesení
#
# 📅 Year: 2017
# 🗓 2017-12-22: 2 usnesení
# 🗓 2017-12-18: 5 usnesení
# 🗓 2017-12-13: 18 usnesení
# 🗓 2017-12-06: 44 usnesení
# 🗓 2017-11-29: 46 usnesení
# 🗓 2017-11-06: 32 usnesení
# 🗓 2017-10-23: 26 usnesení
# 🗓 2017-10-11: 36 usnesení
# 🗓 2017-09-25: 25 usnesení
# 🗓 2017-09-18: 22 usnesení
# 🗓 2017-09-11: 16 usnesení
# 🗓 2017-09-04: 40 usnesení
# 🗓 2017-08-21: 50 usnesení
# 🗓 2017-07-24: 24 usnesení
# 🗓 2017-07-10: 18 usnesení
# 🗓 2017-06-26: 16 usnesení
# 🗓 2017-06-21: 22 usnesení
# 🗓 2017-06-14: 16 usnesení
# 🗓 2017-06-05: 16 usnesení
# 🗓 2017-05-31: 23 usnesení
# 🗓 2017-05-22: 22 usnesení
# 🗓 2017-05-15: 16 usnesení
# 🗓 2017-05-10: 20 usnesení
# 🗓 2017-05-03: 16 usnesení
# 🗓 2017-04-24: 24 usnesení
# 🗓 2017-04-19: 17 usnesení
# 🗓 2017-04-10: 15 usnesení
# 🗓 2017-04-05: 30 usnesení
# 🗓 2017-03-29: 27 usnesení
# 🗓 2017-03-22: 17 usnesení
# 🗓 2017-03-13: 18 usnesení
# 🗓 2017-03-08: 22 usnesení
# 🗓 2017-02-27: 10 usnesení
# 🗓 2017-02-20: 17 usnesení
# 🗓 2017-02-15: 14 usnesení
# 🗓 2017-02-08: 16 usnesení
# 🗓 2017-01-30: 32 usnesení
# 🗓 2017-01-25: 27 usnesení
# 🗓 2017-01-16: 23 usnesení
#
# 📅 Year: 2018
# 🗓 2018-12-17: 21 usnesení
# 🗓 2018-12-12: 24 usnesení
# 🗓 2018-12-03: 19 usnesení
# 🗓 2018-11-29: 20 usnesení
# 🗓 2018-11-20: 16 usnesení
# 🗓 2018-11-14: 32 usnesení
# 🗓 2018-11-07: 15 usnesení
# 🗓 2018-10-31: 16 usnesení
# 🗓 2018-10-24: 18 usnesení
# 🗓 2018-10-17: 23 usnesení
# 🗓 2018-10-10: 19 usnesení
# 🗓 2018-10-03: 26 usnesení
# 🗓 2018-09-26: 9 usnesení
# 🗓 2018-09-19: 11 usnesení
# 🗓 2018-09-12: 17 usnesení
# 🗓 2018-09-04: 11 usnesení
# 🗓 2018-08-29: 15 usnesení
# 🗓 2018-08-22: 25 usnesení
# 🗓 2018-08-15: 17 usnesení
# 🗓 2018-07-31: 16 usnesení
# 🗓 2018-07-24: 17 usnesení
# 🗓 2018-07-18: 11 usnesení
# 🗓 2018-07-10: 6 usnesení
# 🗓 2018-06-27: 16 usnesení
# 🗓 2018-06-26: 15 usnesení
# 🗓 2018-06-22: 32 usnesení
# 🗓 2018-06-19: 18 usnesení
# 🗓 2018-06-13: 12 usnesení
# 🗓 2018-06-06: 13 usnesení
# 🗓 2018-05-30: 24 usnesení
# 🗓 2018-05-23: 24 usnesení
# 🗓 2018-05-16: 5 usnesení
# 🗓 2018-05-09: 11 usnesení
# 🗓 2018-04-30: 12 usnesení
# 🗓 2018-04-23: 24 usnesení
# 🗓 2018-04-18: 20 usnesení
# 🗓 2018-04-11: 6 usnesení
# 🗓 2018-04-04: 20 usnesení
# 🗓 2018-03-27: 18 usnesení
# 🗓 2018-03-21: 19 usnesení
# 🗓 2018-03-14: 10 usnesení
# 🗓 2018-03-08: 11 usnesení
# 🗓 2018-02-27: 19 usnesení
# 🗓 2018-02-21: 14 usnesení
# 🗓 2018-02-14: 17 usnesení
# 🗓 2018-02-07: 16 usnesení
# 🗓 2018-01-31: 10 usnesení
# 🗓 2018-01-24: 19 usnesení
# 🗓 2018-01-17: 10 usnesení
# 🗓 2018-01-10: 1 usnesení
# 🗓 2018-01-08: 25 usnesení
#
# 📅 Year: 2019
# 🗓 2019-12-16: 45 usnesení
# 🗓 2019-12-09: 25 usnesení
# 🗓 2019-11-25: 28 usnesení
# 🗓 2019-11-18: 10 usnesení
# 🗓 2019-11-12: 26 usnesení
# 🗓 2019-11-04: 18 usnesení
# 🗓 2019-10-30: 22 usnesení
# 🗓 2019-10-14: 21 usnesení
# 🗓 2019-10-08: 1 usnesení
# 🗓 2019-10-02: 39 usnesení
# 🗓 2019-09-30: 14 usnesení
# 🗓 2019-09-16: 14 usnesení
# 🗓 2019-09-09: 11 usnesení
# 🗓 2019-09-02: 54 usnesení
# 🗓 2019-08-26: 40 usnesení
# 🗓 2019-07-30: 19 usnesení
# 🗓 2019-07-22: 10 usnesení
# 🗓 2019-07-15: 25 usnesení
# 🗓 2019-07-08: 23 usnesení
# 🗓 2019-07-01: 9 usnesení
# 🗓 2019-06-24: 28 usnesení
# 🗓 2019-06-17: 22 usnesení
# 🗓 2019-06-10: 18 usnesení
# 🗓 2019-06-03: 16 usnesení
# 🗓 2019-05-27: 20 usnesení
# 🗓 2019-05-20: 14 usnesení
# 🗓 2019-05-13: 21 usnesení
# 🗓 2019-05-06: 29 usnesení
# 🗓 2019-04-29: 32 usnesení
# 🗓 2019-04-15: 20 usnesení
# 🗓 2019-04-08: 13 usnesení
# 🗓 2019-04-01: 17 usnesení
# 🗓 2019-03-25: 17 usnesení
# 🗓 2019-03-18: 14 usnesení
# 🗓 2019-03-11: 18 usnesení
# 🗓 2019-03-04: 13 usnesení
# 🗓 2019-02-27: 13 usnesení
# 🗓 2019-02-18: 13 usnesení
# 🗓 2019-02-08: 23 usnesení
# 🗓 2019-02-04: 20 usnesení
# 🗓 2019-01-28: 22 usnesení
# 🗓 2019-01-21: 24 usnesení
# 🗓 2019-01-11: 18 usnesení
#
# 📅 Year: 2020
# 🗓 2020-12-23: 31 usnesení
# 🗓 2020-12-21: 3 usnesení
# 🗓 2020-12-17: 42 usnesení
# 🗓 2020-12-14: 3 usnesení
# 🗓 2020-12-10: 25 usnesení
# 🗓 2020-12-07: 41 usnesení
# 🗓 2020-11-29: 22 usnesení
# 🗓 2020-11-23: 11 usnesení
# 🗓 2020-11-20: 30 usnesení
# 🗓 2020-11-16: 14 usnesení
# 🗓 2020-11-09: 4 usnesení
# 🗓 2020-11-03: 28 usnesení
# 🗓 2020-11-02: 11 usnesení
# 🗓 2020-10-30: 4 usnesení
# 🗓 2020-10-27: 18 usnesení
# 🗓 2020-10-26: 1 usnesení
# 🗓 2020-10-23: 3 usnesení
# 🗓 2020-10-22: 4 usnesení
# 🗓 2020-10-21: 24 usnesení
# 🗓 2020-10-19: 11 usnesení
# 🗓 2020-10-16: 8 usnesení
# 🗓 2020-10-14: 36 usnesení
# 🗓 2020-10-12: 6 usnesení
# 🗓 2020-10-08: 34 usnesení
# 🗓 2020-10-05: 2 usnesení
# 🗓 2020-09-30: 2 usnesení
# 🗓 2020-09-25: 25 usnesení
# 🗓 2020-09-16: 18 usnesení
# 🗓 2020-09-14: 2 usnesení
# 🗓 2020-09-09: 27 usnesení
# 🗓 2020-09-07: 1 usnesení
# 🗓 2020-09-02: 32 usnesení
# 🗓 2020-08-24: 33 usnesení
# 🗓 2020-08-17: 45 usnesení
# 🗓 2020-07-27: 21 usnesení
# 🗓 2020-07-20: 42 usnesení
# 🗓 2020-07-13: 25 usnesení
# 🗓 2020-06-29: 19 usnesení
# 🗓 2020-06-22: 27 usnesení
# 🗓 2020-06-15: 30 usnesení
# 🗓 2020-06-08: 2 usnesení
# 🗓 2020-06-05: 24 usnesení
# 🗓 2020-06-01: 26 usnesení
# 🗓 2020-05-25: 17 usnesení
# 🗓 2020-05-18: 16 usnesení
# 🗓 2020-05-11: 8 usnesení
# 🗓 2020-05-07: 18 usnesení
# 🗓 2020-05-04: 12 usnesení
# 🗓 2020-04-30: 22 usnesení
# 🗓 2020-04-27: 6 usnesení
# 🗓 2020-04-24: 15 usnesení
# 🗓 2020-04-23: 19 usnesení
# 🗓 2020-04-20: 5 usnesení
# 🗓 2020-04-17: 6 usnesení
# 🗓 2020-04-14: 16 usnesení
# 🗓 2020-04-09: 14 usnesení
# 🗓 2020-04-06: 27 usnesení
# 🗓 2020-04-01: 5 usnesení
# 🗓 2020-03-31: 38 usnesení
# 🗓 2020-03-30: 13 usnesení
# 🗓 2020-03-26: 1 usnesení
# 🗓 2020-03-24: 29 usnesení
# 🗓 2020-03-23: 15 usnesení
# 🗓 2020-03-19: 10 usnesení
# 🗓 2020-03-18: 2 usnesení
# 🗓 2020-03-17: 14 usnesení
# 🗓 2020-03-16: 16 usnesení
# 🗓 2020-03-15: 1 usnesení
# 🗓 2020-03-14: 8 usnesení
# 🗓 2020-03-13: 9 usnesení
# 🗓 2020-03-12: 18 usnesení
# 🗓 2020-03-09: 22 usnesení
# 🗓 2020-03-02: 28 usnesení
# 🗓 2020-02-24: 18 usnesení
# 🗓 2020-02-17: 21 usnesení
# 🗓 2020-02-03: 18 usnesení
# 🗓 2020-01-27: 20 usnesení
# 🗓 2020-01-20: 25 usnesení
# 🗓 2020-01-13: 23 usnesení
#
# 📅 Year: 2021
# 🗓 2021-12-29: 8 usnesení
# 🗓 2021-12-22: 7 usnesení
# 🗓 2021-12-17: 55 usnesení
# 🗓 2021-12-13: 1 usnesení
# 🗓 2021-12-08: 35 usnesení
# 🗓 2021-12-06: 3 usnesení
# 🗓 2021-11-29: 2 usnesení
# 🗓 2021-11-26: 19 usnesení
# 🗓 2021-11-25: 26 usnesení
# 🗓 2021-11-22: 6 usnesení
# 🗓 2021-11-19: 5 usnesení
# 🗓 2021-11-18: 9 usnesení
# 🗓 2021-11-15: 14 usnesení
# 🗓 2021-11-12: 1 usnesení
# 🗓 2021-11-11: 8 usnesení
# 🗓 2021-11-10: 45 usnesení
# 🗓 2021-11-05: 2 usnesení
# 🗓 2021-11-01: 31 usnesení
# 🗓 2021-10-25: 7 usnesení
# 🗓 2021-10-20: 16 usnesení
# 🗓 2021-10-18: 34 usnesení
# 🗓 2021-10-11: 6 usnesení
# 🗓 2021-10-04: 20 usnesení
# 🗓 2021-09-27: 14 usnesení
# 🗓 2021-09-20: 44 usnesení
# 🗓 2021-09-13: 2 usnesení
# 🗓 2021-09-10: 16 usnesení
# 🗓 2021-08-30: 44 usnesení
# 🗓 2021-08-23: 2 usnesení
# 🗓 2021-08-19: 5 usnesení
# 🗓 2021-08-16: 1 usnesení
# 🗓 2021-08-09: 4 usnesení
# 🗓 2021-07-30: 35 usnesení
# 🗓 2021-07-26: 33 usnesení
# 🗓 2021-07-19: 27 usnesení
# 🗓 2021-07-12: 1 usnesení
# 🗓 2021-07-07: 2 usnesení
# 🗓 2021-07-01: 28 usnesení
# 🗓 2021-06-28: 1 usnesení
# 🗓 2021-06-25: 23 usnesení
# 🗓 2021-06-21: 20 usnesení
# 🗓 2021-06-14: 23 usnesení
# 🗓 2021-06-07: 23 usnesení
# 🗓 2021-05-31: 1 usnesení
# 🗓 2021-05-28: 11 usnesení
# 🗓 2021-05-24: 3 usnesení
# 🗓 2021-05-21: 20 usnesení
# 🗓 2021-05-17: 2 usnesení
# 🗓 2021-05-14: 11 usnesení
# 🗓 2021-05-10: 5 usnesení
# 🗓 2021-05-06: 9 usnesení
# 🗓 2021-05-03: 5 usnesení
# 🗓 2021-04-29: 23 usnesení
# 🗓 2021-04-26: 1 usnesení
# 🗓 2021-04-23: 1 usnesení
# 🗓 2021-04-22: 19 usnesení
# 🗓 2021-04-19: 22 usnesení
# 🗓 2021-04-12: 12 usnesení
# 🗓 2021-04-06: 24 usnesení
# 🗓 2021-03-29: 4 usnesení
# 🗓 2021-03-26: 10 usnesení
# 🗓 2021-03-22: 9 usnesení
# 🗓 2021-03-18: 14 usnesení
# 🗓 2021-03-15: 30 usnesení
# 🗓 2021-03-08: 3 usnesení
# 🗓 2021-03-05: 1 usnesení
# 🗓 2021-03-03: 4 usnesení
# 🗓 2021-03-02: 24 usnesení
# 🗓 2021-03-01: 1 usnesení
# 🗓 2021-02-28: 22 usnesení
# 🗓 2021-02-26: 2 usnesení
# 🗓 2021-02-25: 4 usnesení
# 🗓 2021-02-24: 14 usnesení
# 🗓 2021-02-22: 1 usnesení
# 🗓 2021-02-19: 30 usnesení
# 🗓 2021-02-15: 20 usnesení
# 🗓 2021-02-14: 1 usnesení
# 🗓 2021-02-12: 3 usnesení
# 🗓 2021-02-11: 19 usnesení
# 🗓 2021-02-08: 20 usnesení
# 🗓 2021-02-01: 4 usnesení
# 🗓 2021-01-28: 1 usnesení
# 🗓 2021-01-27: 19 usnesení
# 🗓 2021-01-25: 3 usnesení
# 🗓 2021-01-22: 20 usnesení
# 🗓 2021-01-18: 1 usnesení
# 🗓 2021-01-13: 17 usnesení
# 🗓 2021-01-11: 5 usnesení
# 🗓 2021-01-07: 11 usnesení
#
# 📅 Year: 2022
# 🗓 2022-12-21: 30 usnesení
# 🗓 2022-12-14: 27 usnesení
# 🗓 2022-12-07: 13 usnesení
# 🗓 2022-11-30: 36 usnesení
# 🗓 2022-11-23: 15 usnesení
# 🗓 2022-11-16: 23 usnesení
# 🗓 2022-11-09: 18 usnesení
# 🗓 2022-11-02: 20 usnesení
# 🗓 2022-10-27: 17 usnesení
# 🗓 2022-10-19: 11 usnesení
# 🗓 2022-10-12: 21 usnesení
# 🗓 2022-10-05: 21 usnesení
# 🗓 2022-09-26: 16 usnesení
# 🗓 2022-09-21: 28 usnesení
# 🗓 2022-09-14: 2 usnesení
# 🗓 2022-09-12: 13 usnesení
# 🗓 2022-09-07: 21 usnesení
# 🗓 2022-08-31: 26 usnesení
# 🗓 2022-08-24: 35 usnesení
# 🗓 2022-08-17: 1 usnesení
# 🗓 2022-07-28: 25 usnesení
# 🗓 2022-07-27: 19 usnesení
# 🗓 2022-07-20: 26 usnesení
# 🗓 2022-07-13: 28 usnesení
# 🗓 2022-06-29: 42 usnesení
# 🗓 2022-06-22: 16 usnesení
# 🗓 2022-06-15: 27 usnesení
# 🗓 2022-06-08: 27 usnesení
# 🗓 2022-06-01: 22 usnesení
# 🗓 2022-05-25: 24 usnesení
# 🗓 2022-05-18: 2 usnesení
# 🗓 2022-05-17: 22 usnesení
# 🗓 2022-05-11: 22 usnesení
# 🗓 2022-05-04: 18 usnesení
# 🗓 2022-04-27: 11 usnesení
# 🗓 2022-04-20: 20 usnesení
# 🗓 2022-04-13: 29 usnesení
# 🗓 2022-04-06: 25 usnesení
# 🗓 2022-03-30: 29 usnesení
# 🗓 2022-03-23: 15 usnesení
# 🗓 2022-03-16: 33 usnesení
# 🗓 2022-03-09: 3 usnesení
# 🗓 2022-03-03: 21 usnesení
# 🗓 2022-03-02: 2 usnesení
# 🗓 2022-02-27: 1 usnesení
# 🗓 2022-02-26: 9 usnesení
# 🗓 2022-02-25: 26 usnesení
# 🗓 2022-02-23: 16 usnesení
# 🗓 2022-02-16: 12 usnesení
# 🗓 2022-02-09: 10 usnesení
# 🗓 2022-02-02: 27 usnesení
# 🗓 2022-01-26: 17 usnesení
# 🗓 2022-01-19: 7 usnesení
# 🗓 2022-01-12: 3 usnesení
# 🗓 2022-01-06: 8 usnesení
#
# 📅 Year: 2023
# 🗓 2023-12-21: 35 usnesení
# 🗓 2023-12-20: 32 usnesení
# 🗓 2023-12-13: 9 usnesení
# 🗓 2023-12-06: 1 usnesení
# 🗓 2023-12-01: 26 usnesení
# 🗓 2023-11-29: 1 usnesení
# 🗓 2023-11-25: 34 usnesení
# 🗓 2023-11-22: 23 usnesení
# 🗓 2023-11-15: 20 usnesení
# 🗓 2023-11-08: 19 usnesení
# 🗓 2023-11-01: 15 usnesení
# 🗓 2023-10-25: 17 usnesení
# 🗓 2023-10-18: 23 usnesení
# 🗓 2023-10-11: 13 usnesení
# 🗓 2023-10-04: 29 usnesení
# 🗓 2023-09-27: 2 usnesení
# 🗓 2023-09-20: 15 usnesení
# 🗓 2023-09-13: 12 usnesení
# 🗓 2023-09-06: 30 usnesení
# 🗓 2023-08-30: 1 usnesení
# 🗓 2023-08-29: 27 usnesení
# 🗓 2023-08-23: 35 usnesení
# 🗓 2023-08-16: 15 usnesení
# 🗓 2023-07-26: 26 usnesení
# 🗓 2023-07-19: 29 usnesení
# 🗓 2023-07-12: 31 usnesení
# 🗓 2023-06-28: 24 usnesení
# 🗓 2023-06-21: 33 usnesení
# 🗓 2023-06-14: 1 usnesení
# 🗓 2023-06-08: 6 usnesení
# 🗓 2023-06-07: 8 usnesení
# 🗓 2023-05-31: 23 usnesení
# 🗓 2023-05-24: 13 usnesení
# 🗓 2023-05-17: 22 usnesení
# 🗓 2023-05-10: 2 usnesení
# 🗓 2023-05-04: 28 usnesení
# 🗓 2023-05-03: 22 usnesení
# 🗓 2023-04-26: 14 usnesení
# 🗓 2023-04-19: 19 usnesení
# 🗓 2023-04-12: 16 usnesení
# 🗓 2023-04-05: 9 usnesení
# 🗓 2023-03-29: 23 usnesení
# 🗓 2023-03-22: 11 usnesení
# 🗓 2023-03-15: 16 usnesení
# 🗓 2023-03-08: 12 usnesení
# 🗓 2023-03-01: 17 usnesení
# 🗓 2023-02-22: 1 usnesení
# 🗓 2023-02-20: 15 usnesení
# 🗓 2023-02-15: 13 usnesení
# 🗓 2023-02-08: 26 usnesení
# 🗓 2023-02-01: 1 usnesení
# 🗓 2023-01-27: 16 usnesení
# 🗓 2023-01-25: 14 usnesení
# 🗓 2023-01-18: 14 usnesení
# 🗓 2023-01-11: 17 usnesení
#
# 📅 Year: 2024
# 🗓 2024-12-18: 31 usnesení
# 🗓 2024-12-11: 24 usnesení
# 🗓 2024-12-04: 38 usnesení
# 🗓 2024-11-27: 24 usnesení
# 🗓 2024-11-20: 24 usnesení
# 🗓 2024-11-13: 31 usnesení
# 🗓 2024-11-06: 14 usnesení
# 🗓 2024-10-30: 18 usnesení
# 🗓 2024-10-23: 1 usnesení
# 🗓 2024-10-21: 20 usnesení
# 🗓 2024-10-16: 23 usnesení
# 🗓 2024-10-10: 26 usnesení
# 🗓 2024-10-02: 21 usnesení
# 🗓 2024-09-25: 17 usnesení
# 🗓 2024-09-18: 2 usnesení
# 🗓 2024-09-16: 13 usnesení
# 🗓 2024-09-11: 11 usnesení
# 🗓 2024-09-04: 25 usnesení
# 🗓 2024-08-28: 39 usnesení
# 🗓 2024-08-21: 28 usnesení
# 🗓 2024-07-24: 14 usnesení
# 🗓 2024-07-17: 24 usnesení
# 🗓 2024-07-10: 13 usnesení
# 🗓 2024-07-03: 29 usnesení
# 🗓 2024-06-26: 11 usnesení
# 🗓 2024-06-19: 31 usnesení
# 🗓 2024-06-12: 15 usnesení
# 🗓 2024-06-05: 12 usnesení
# 🗓 2024-05-29: 18 usnesení
# 🗓 2024-05-22: 1 usnesení
# 🗓 2024-05-16: 15 usnesení
# 🗓 2024-05-15: 19 usnesení
# 🗓 2024-05-07: 14 usnesení
# 🗓 2024-04-30: 22 usnesení
# 🗓 2024-04-24: 10 usnesení
# 🗓 2024-04-17: 19 usnesení
# 🗓 2024-04-10: 27 usnesení
# 🗓 2024-04-03: 16 usnesení
# 🗓 2024-03-27: 14 usnesení
# 🗓 2024-03-20: 3 usnesení
# 🗓 2024-03-13: 17 usnesení
# 🗓 2024-03-06: 11 usnesení
# 🗓 2024-02-28: 12 usnesení
# 🗓 2024-02-21: 12 usnesení
# 🗓 2024-02-14: 19 usnesení
# 🗓 2024-02-07: 10 usnesení
# 🗓 2024-01-31: 9 usnesení
# 🗓 2024-01-24: 21 usnesení
# 🗓 2024-01-17: 11 usnesení
# 🗓 2024-01-10: 21 usnesení
#
# 📅 Year: 2025
# 🗓 2025-04-30: 17 usnesení
# 🗓 2025-04-23: 18 usnesení
# 🗓 2025-04-16: 15 usnesení
# 🗓 2025-04-09: 1 usnesení
# 🗓 2025-04-03: 22 usnesení
# 🗓 2025-04-02: 1 usnesení
# 🗓 2025-03-27: 17 usnesení
# 🗓 2025-03-26: 30 usnesení
# 🗓 2025-03-19: 1 usnesení
# 🗓 2025-03-16: 16 usnesení
# 🗓 2025-03-12: 13 usnesení
# 🗓 2025-03-05: 20 usnesení
# 🗓 2025-02-26: 15 usnesení
# 🗓 2025-02-19: 13 usnesení
# 🗓 2025-02-12: 9 usnesení
# 🗓 2025-02-05: 26 usnesení
# 🗓 2025-01-29: 12 usnesení
# 🗓 2025-01-22: 14 usnesení
# 🗓 2025-01-15: 24 usnesení
#
# ✅ Saved to usneseni_by_year.json

# %% [markdown]
# ### Download files

# %%
def extract_date_from_url(url):
    """
    Extracts the date string from a meeting detail URL.

    Args:
        url (str): URL containing the meeting date in the format /jednani-detail/YYYY-MM-DD

    Returns:
        str or None: Extracted date string (YYYY-MM-DD), or None if not found.
    """
    match = re.search(r'/jednani-detail/(\d{4}-\d{2}-\d{2})', url)
    if match:
        return match.group(1)
    return None

def download_meeting_records(year, meeting_url):
    """
    Downloads government meeting recording files ("Záznam z jednání") from a specific meeting page.

    Args:
        year (int): The year of the meeting (used for folder organization).
        meeting_url (str): Full URL to the meeting detail page.
    """
    date_str = extract_date_from_url(meeting_url)
    if not date_str:
        print(f"Could not extract date from URL: {meeting_url}")
        return

    # Request the content of the meeting detail page
    res = requests.get(meeting_url, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")

    # Find all mentions of "Záznam z jednání" (Record of meeting)
    records = soup.find_all("span", string=re.compile("Záznam z jednání"))
    if not records:
        # Find the parent element containing the download link
        print(f"No Záznam z jednání in: {meeting_url}")
        return

    # Find a download link within the parent that matches the expected pattern
    for record in records:
        parent = record.find_parent()
        if not parent:
            continue

        a_tag = parent.find("a", href=re.compile("/portal/services/download/attachment/"))
        if a_tag:
            file_url = BASE_URL + a_tag["href"]  # Construct full download URL
            extension = os.path.splitext(file_url)[1]  # Get file extension e.g. ".doc", ".pdf"
            doc_type = a_tag.text.strip().lower() # Text label for the download link 

            folder = f"vlada_zaznamy/{year}"
            os.makedirs(folder, exist_ok=True)
            filepath = os.path.join(folder, f"{date_str}.doc")

            # Avoid re-downloading if the file already exists
            if not os.path.exists(filepath):
                file_res = requests.get(file_url, headers=HEADERS)
                with open(filepath, "wb") as f:
                    f.write(file_res.content)
                print(f"Downloaded: {filepath}")
                time.sleep(0.5) # be polite

# %%
def download_all_records(links_dict):
    """
    Iterates through all years and meeting URLs, downloading the official records
    ("Záznam z jednání") for each government meeting.

    Args:
        links_dict (dict): Dictionary mapping years to lists of meeting URLs,
                           e.g., {"2012": [url1, url2, ...], ...}
    """
    for year, urls in links_dict.items():
        print(f"\nDownloading year: {year}")
        print(urls)
        # Use tqdm to display progress bar for each year's downloads
        for url in tqdm(urls, desc=f"Year {year}"):
            try:
                download_meeting_records(year, url)
            except Exception as e:
                print(f"Error in {url}: {e}")
            time.sleep(0.5) # be polite

# %%
with open(URLS, "r", encoding="utf-8") as f:
    links = json.load(f)
download_all_records(links)

# %% [markdown]
# ## Scrape 1991-2008

# %%
import os
import requests
from bs4 import BeautifulSoup

BASE_INDEX_URL = "https://albatros.odok.gov.cz/usneseni/usneseni_webtest.nsf/web/cs?Open&"
BASE_PAGE_URL = "https://albatros.odok.gov.cz/usneseni/usneseni_webtest.nsf/web/"
BASE_DOC_ROOT = "https://albatros.odok.gov.cz/usneseni/usneseni_webtest.nsf"

def extract_meeting_links(year):
    index_url = BASE_INDEX_URL + str(year)
    res = requests.get(index_url, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")

    links = []
    for a in soup.find_all("a", href=True):
        if re.match(r"cs\?Open&\d{4}&\d{2}-\d{2}", a["href"]):
            full_url = requests.compat.urljoin(BASE_PAGE_URL, a["href"])
            date_str = a.text.strip()  # e.g. 1991-12-20
            links.append((date_str, full_url))
    return links

def download_zaznam_from_detail(date_str, year, detail_url):
    res = requests.get(detail_url, headers=HEADERS)
    soup = BeautifulSoup(res.content, "html.parser")

    # Find link with exact label
    link = soup.find("a", string=re.compile(r"Záznam z jednání", re.IGNORECASE))
    if not link:
        print(f"❌ No Záznam z jednání found on {detail_url}")
        return

    href = link.get("href")
    if href.startswith("../0/"):
        doc_id = href.split("../0/")[1]
        file_url = f"{BASE_DOC_ROOT}/0/{doc_id}"
    elif href.startswith("/0/"):
        file_url = f"{BASE_DOC_ROOT}{href}"
    else:
        print(f"⚠️ Unexpected href format: {href}")
        return

    folder = os.path.join("vlada_zaznamy", str(year))
    os.makedirs(folder, exist_ok=True)
    filename = f"{date_str}.doc"
    filepath = os.path.join(folder, filename)

    if not os.path.exists(filepath):
        try:
            file_res = requests.get(file_url, headers=HEADERS)
            if file_res.status_code == 200:
                with open(filepath, "wb") as f:
                    f.write(file_res.content)
                print(f"✅ Downloaded: {filepath}")
            else:
                print(f"❌ Failed to download {file_url} (status {file_res.status_code})")
        except Exception as e:
            print(f"❌ Error downloading {file_url}: {e}")
    time.sleep(0.5)  # be polite
                

def download_all(start_year=1991, end_year=2008):
    for year in range(start_year, end_year + 1):
        print(f"\n📅 Year {year}")
        try:
            meetings = extract_meeting_links(year)
            print(f"Found {len(meetings)} meetings")
            for date_str, url in meetings:
                download_zaznam_from_detail(date_str, year, url)
        except Exception as e:
            print(f"⚠️ Error for year {year}: {e}")
        time.sleep(0.5)
download_all()
# Out:
# 📅 Year 1991
# Found 51 meetings
# Found link: ../0/9470577DAD234F34C12571B6006D930B
# Found link: ../0/4E24E1AD5668F4DAC12571B6006CC485
# ✅ Downloaded: vlada_zaznamy\1991\1991-12-12.doc
# Found link: ../0/17F0D82CC1783F8EC12571B60070EA36
# ✅ Downloaded: vlada_zaznamy\1991\1991-12-11.doc
# Found link: ../0/6DA127793DC129E2C12571B6006C9B60
# ✅ Downloaded: vlada_zaznamy\1991\1991-12-04.doc
# Found link: ../0/63DE5048F90B7805C12571B6006DDB86
# ✅ Downloaded: vlada_zaznamy\1991\1991-12-01.doc
# Found link: ../0/F7BA7FE08CDF49FEC12571B6006FEC8E
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-29.doc
# Found link: ../0/E7A09789B9F3A601C12571B6006EF487
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-27.doc
# Found link: ../0/5D404A4F90BCDA05C12571B6006CE3F7
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-20.doc
# Found link: ../0/C811E3202598C95BC12571B6006C3C6C
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-19.doc
# Found link: ../0/32ABF3651188A08EC12571B6006D23B1
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-18.doc
# Found link: ../0/3028D1824C50A7F0C12571B6006C83DD
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-13.doc
# Found link: ../0/2B59376248219977C12571B6006D77A8
# ✅ Downloaded: vlada_zaznamy\1991\1991-11-06.doc
# Found link: ../0/E6E4F6A9D388E647C12571B6006C2C3E
# ✅ Downloaded: vlada_zaznamy\1991\1991-10-30.doc
# Found link: ../0/46D5238A44AB53A6C12571B6006FF01C
# ✅ Downloaded: vlada_zaznamy\1991\1991-10-23.doc
# Found link: ../0/A58A19D9DABCB345C12571B6006D112B
# ✅ Downloaded: vlada_zaznamy\1991\1991-10-16.doc
# Found link: ../0/3400FDD9E1CF77DFC12571B6006BF75B
# ✅ Downloaded: vlada_zaznamy\1991\1991-10-09.doc
# Found link: ../0/69CA96F663FE1247C12571B6006FD45D
# ✅ Downloaded: vlada_zaznamy\1991\1991-10-02.doc
# Found link: ../0/71851C13AAB2ACBFC12571B6006F8956
# ✅ Downloaded: vlada_zaznamy\1991\1991-09-25.doc
# Found link: ../0/E61894B37C47B4EFC12571B6006D695D
# ✅ Downloaded: vlada_zaznamy\1991\1991-09-18.doc
# Found link: ../0/9C9B0113FAAF173AC12571B6006D31A9
# ✅ Downloaded: vlada_zaznamy\1991\1991-09-11.doc
# Found link: ../0/EEDAF091D70A95C8C12571B6006CE9AD
# ✅ Downloaded: vlada_zaznamy\1991\1991-09-04.doc
# Found link: ../0/2FE6BF3AB64C5189C12571B6006C7D41
# ✅ Downloaded: vlada_zaznamy\1991\1991-08-28.doc
# Found link: ../0/FEA0E9F40AC06D10C12571B6006F41AD
# ✅ Downloaded: vlada_zaznamy\1991\1991-08-21.doc
# Found link: ../0/9846574CAC075C1DC12571B6006C98E7
# ✅ Downloaded: vlada_zaznamy\1991\1991-08-14.doc
# Found link: ../0/3107DA8F80C31DD1C12571B6006ED7F2
# ✅ Downloaded: vlada_zaznamy\1991\1991-07-22.doc
# Found link: ../0/3EC0C414382C0685C12571B6006BF925
# ✅ Downloaded: vlada_zaznamy\1991\1991-07-17.doc
# Found link: ../0/B20CE8C25EC65BEBC12571B6006FDB31
# ✅ Downloaded: vlada_zaznamy\1991\1991-07-10.doc
# Found link: ../0/8D0A1B3597BE9012C12571B6006E7E91
# ✅ Downloaded: vlada_zaznamy\1991\1991-07-03.doc
# Found link: ../0/E495DF669DCECCA2C12571B6006EB2E7
# ✅ Downloaded: vlada_zaznamy\1991\1991-06-26.doc
# Found link: ../0/FB10A3924F2A77A8C12571B6006C62B4
# ✅ Downloaded: vlada_zaznamy\1991\1991-06-14.doc
# Found link: ../0/FC089A9BCB62590FC12571B6006E41DF
# ✅ Downloaded: vlada_zaznamy\1991\1991-06-12.doc
# Found link: ../0/A99DA7F1BE4D8AA7C12571B6006C698F
# ✅ Downloaded: vlada_zaznamy\1991\1991-06-05.doc
# Found link: ../0/08876C7716A853EBC1257D4F0042D681
# ✅ Downloaded: vlada_zaznamy\1991\1991-05-29.doc
# Found link: ../0/10E2EFFE806AD843C1257D4F00347564
# ✅ Downloaded: vlada_zaznamy\1991\1991-05-15.doc
# Found link: ../0/A0E41CC9D3FAA2FCC12571B6006BD3DB
# ✅ Downloaded: vlada_zaznamy\1991\1991-05-08.doc
# Found link: ../0/165E3EF506C30B98C12571B6007092F6
# ✅ Downloaded: vlada_zaznamy\1991\1991-05-03.doc
# Found link: ../0/461EB5E5E5B53312C12571B6006C0E7B
# ✅ Downloaded: vlada_zaznamy\1991\1991-04-29.doc
# Found link: ../0/9E81111CAEAFD950C12571B60070C84C
# ✅ Downloaded: vlada_zaznamy\1991\1991-04-17.doc
# Found link: ../0/9057EC1D133644E5C12571B60070D57B
# ✅ Downloaded: vlada_zaznamy\1991\1991-04-11.doc
# Found link: ../0/1F6EF48C1B946FFCC12571B6006C1177
# ✅ Downloaded: vlada_zaznamy\1991\1991-04-03.doc
# Found link: ../0/BFA6BF8E4A99160FC12571B6006DDB1F
# ✅ Downloaded: vlada_zaznamy\1991\1991-03-20.doc
# Found link: ../0/CDEC3558F76D4CD9C12571B6006DC1E5
# ✅ Downloaded: vlada_zaznamy\1991\1991-03-13.doc
# Found link: ../0/2C0EEAB662EE195BC12571B6006C6447
# ✅ Downloaded: vlada_zaznamy\1991\1991-03-06.doc
# Found link: ../0/BE598E6965F7F73EC12571B6006EFB7E
# ✅ Downloaded: vlada_zaznamy\1991\1991-02-20.doc
# Found link: ../0/E52F82E762365083C12571B6006D11D3
# ✅ Downloaded: vlada_zaznamy\1991\1991-02-18.doc
# Found link: ../0/752C53BE51229508C12571B60070CFBF
# ✅ Downloaded: vlada_zaznamy\1991\1991-02-13.doc
# Found link: ../0/2F85E63A57F9FDE6C12571B6006D3CBC
# ✅ Downloaded: vlada_zaznamy\1991\1991-02-02.doc
# Found link: ../0/06FFB9C4A409D0D3C12571B6006EF255
# ✅ Downloaded: vlada_zaznamy\1991\1991-01-30.doc
# Found link: ../0/1F9B6363EB50ECD3C12571B6006B0EC3
# ✅ Downloaded: vlada_zaznamy\1991\1991-01-23.doc
# Found link: ../0/EEA4991DB7F2AA6CC12571B6007029A4
# ✅ Downloaded: vlada_zaznamy\1991\1991-01-16.doc
# Found link: ../0/D77AB773C1CB35B4C12571B6006DB474
# ✅ Downloaded: vlada_zaznamy\1991\1991-01-09.doc
#
# 📅 Year 1992
# Found 61 meetings
# Found link: ../0/09F68CD92E56AFBDC12571B6006C7548
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-30.doc
# Found link: ../0/66D91A7BC56A2452C12571B6006C454A
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-23.doc
# Found link: ../0/7DC52B92E44DF2FCC12571B6006D2F6D
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-18.doc
# Found link: ../0/3E022DB1349863DBC12571B6006BEC2B
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-13.doc
# Found link: ../0/36F8A7CA7C6A30E5C12571B6006D2C4A
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-09.doc
# Found link: ../0/F667FDEDE2CD67E3C12571B6006E23AE
# ✅ Downloaded: vlada_zaznamy\1992\1992-12-02.doc
# Found link: ../0/DED2AB86EC2AF9F9C12571B6006CEFFE
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-27.doc
# Found link: ../0/C8F28663228A8FEDC12571B6006C6D32
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-25.doc
# Found link: ../0/632FD298C48C74C4C12571B6006EB791
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-18.doc
# Found link: ../0/76A40F7227C7AF0EC12571B6006BF3E6
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-11.doc
# Found link: ../0/7F22C4BEF62C1FF2C12571B6006BBCEF
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-04.doc
# Found link: ../0/537B6F8F59E9A5D7C12571B6006FE292
# ✅ Downloaded: vlada_zaznamy\1992\1992-11-01.doc
# Found link: ../0/C01514F289449381C12571B6006FF304
# ✅ Downloaded: vlada_zaznamy\1992\1992-10-28.doc
# Found link: ../0/19C1924244BBB9C7C12571B6006EA496
# ✅ Downloaded: vlada_zaznamy\1992\1992-10-21.doc
# Found link: ../0/EBA57B9D83A656D0C12571B6006BF6C8
# ✅ Downloaded: vlada_zaznamy\1992\1992-10-14.doc
# Found link: ../0/A9B3C7B414DE0B08C12571B600705489
# ✅ Downloaded: vlada_zaznamy\1992\1992-10-07.doc
# Found link: ../0/4E11B789F1D3BE6BC12571B6006E873D
# ✅ Downloaded: vlada_zaznamy\1992\1992-10-03.doc
# Found link: ../0/789655F70C2AD186C12571B6006D0C8C
# ✅ Downloaded: vlada_zaznamy\1992\1992-09-30.doc
# Found link: ../0/782971E4B8040A4BC12571B6006CF013
# ✅ Downloaded: vlada_zaznamy\1992\1992-09-23.doc
# Found link: ../0/4642DBFB341402EFC12571B6007016B8
# ✅ Downloaded: vlada_zaznamy\1992\1992-09-16.doc
# Found link: ../0/44FD8678D920C3CEC12571B6006B61CE
# ✅ Downloaded: vlada_zaznamy\1992\1992-09-09.doc
# Found link: ../0/5FFF499816753FF3C12571B6007023B2
# ✅ Downloaded: vlada_zaznamy\1992\1992-09-02.doc
# Found link: ../0/5C51FE6993285FEFC12571B6006EC5C2
# ✅ Downloaded: vlada_zaznamy\1992\1992-08-26.doc
# Found link: ../0/51066023EE13D0E6C12571B6006CD8C5
# ✅ Downloaded: vlada_zaznamy\1992\1992-08-19.doc
# Found link: ../0/71B4D589BECE3FBDC12571B6006CDB3C
# ✅ Downloaded: vlada_zaznamy\1992\1992-08-12.doc
# Found link: ../0/C3C6BDEE3C8415C2C12571B6006EB3F2
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-29.doc
# Found link: ../0/8128B949B467FBABC12571B6006D88D3
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-22.doc
# Found link: ../0/BD04768278B57A1BC12571B6006FDC7B
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-17.doc
# Found link: ../0/39A3303A34ACE763C12571B6006CF337
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-10.doc
# Found link: ../0/AD48306D25B3FCBFC12571B6006EA2FE
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-08.doc
# Found link: ../0/FDD50BE151917DAAC12571B6006D7DA0
# ✅ Downloaded: vlada_zaznamy\1992\1992-07-02.doc
# Found link: ../0/E772B288B25C1BF5C12571B6006E2E16
# ✅ Downloaded: vlada_zaznamy\1992\1992-06-29.doc
# Found link: ../0/23AC23C85BD4585FC12571B60070137F
# ✅ Downloaded: vlada_zaznamy\1992\1992-06-25.doc
# Found link: ../0/890D447E3A4238DDC12571B6006B022A
# ✅ Downloaded: vlada_zaznamy\1992\1992-06-17.doc
# Found link: ../0/1B57DB50908182F6C12571B6006D7BE1
# ✅ Downloaded: vlada_zaznamy\1992\1992-06-15.doc
# Found link: ../0/5EC74B129D4DE9A8C12571B6006C999F
# ✅ Downloaded: vlada_zaznamy\1992\1992-06-10.doc
# Found link: ../0/1AB8BECA0FE666D9C12571B60070FC5D
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-27.doc
# Found link: ../0/AABA33CD7DE165CCC12571B6006CA0D3
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-20.doc
# Found link: ../0/59AA6B479C5D4297C12571B6006F6049
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-13.doc
# Found link: ../0/DE89B56882EFAB9FC12571B6006BA9ED
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-11.doc
# Found link: ../0/FC6338BA4D787203C12571B6006CAE71
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-06.doc
# Found link: ../0/FB4498E6EA85DE0DC12571B6006D2331
# ✅ Downloaded: vlada_zaznamy\1992\1992-05-04.doc
# Found link: ../0/EA648DEA99C8F5EDC12571B6006B0D1D
# ✅ Downloaded: vlada_zaznamy\1992\1992-04-29.doc
# Found link: ../0/8D51B08BB75D759EC12571B6006F4B7C
# ✅ Downloaded: vlada_zaznamy\1992\1992-04-22.doc
# Found link: ../0/763253B62909E67AC12571B6006E5980
# ✅ Downloaded: vlada_zaznamy\1992\1992-04-15.doc
# Found link: ../0/60F94AEAF54F3242C12571B6006C1152
# ✅ Downloaded: vlada_zaznamy\1992\1992-04-08.doc
# Found link: ../0/D1CE79A349FB7626C12571B60070C289
# ✅ Downloaded: vlada_zaznamy\1992\1992-04-01.doc
# Found link: ../0/E31FF8B964D0B8E9C12571B60070ECAC
# ✅ Downloaded: vlada_zaznamy\1992\1992-03-25.doc
# Found link: ../0/990AC0F03086E755C12571B6006F92EC
# ✅ Downloaded: vlada_zaznamy\1992\1992-03-18.doc
# Found link: ../0/C239F3DB63A8FF0BC12571B6006D1DD5
# ✅ Downloaded: vlada_zaznamy\1992\1992-03-15.doc
# Found link: ../0/82FF2886B65CD4B9C12571B6006FE75A
# ✅ Downloaded: vlada_zaznamy\1992\1992-03-04.doc
# Found link: ../0/EF7D096C3EFF1A05C12571B60070EA2A
# ✅ Downloaded: vlada_zaznamy\1992\1992-02-26.doc
# Found link: ../0/FDF1D08FA4DB79A7C12571B6006FC425
# ✅ Downloaded: vlada_zaznamy\1992\1992-02-19.doc
# Found link: ../0/EEAEDE7374422293C12571B6006AF0EF
# ✅ Downloaded: vlada_zaznamy\1992\1992-02-13.doc
# Found link: ../0/34012464EE8E5A59C12571B6006D2A1C
# ✅ Downloaded: vlada_zaznamy\1992\1992-02-12.doc
# Found link: ../0/419CD6FBC9744446C12571B6006D969D
# ✅ Downloaded: vlada_zaznamy\1992\1992-02-04.doc
# Found link: ../0/CFF31538D45A7EE6C12571B6006CAA1D
# ✅ Downloaded: vlada_zaznamy\1992\1992-01-29.doc
# Found link: ../0/343D9FDE4C9086E0C12571B6006BA5AC
# ✅ Downloaded: vlada_zaznamy\1992\1992-01-22.doc
# Found link: ../0/FC479863ED4E0161C12571B6006D70BF
# ✅ Downloaded: vlada_zaznamy\1992\1992-01-20.doc
# Found link: ../0/F2F2F5AD63C3692FC12571B6006B0D27
# ✅ Downloaded: vlada_zaznamy\1992\1992-01-15.doc
# Found link: ../0/24DE9E3065710293C12571B60070E2B5
# ✅ Downloaded: vlada_zaznamy\1992\1992-01-08.doc
#
# 📅 Year 1993
# Found 51 meetings
# Found link: ../0/F200B9BCC28459D4C12571B6006E3C0D
# ✅ Downloaded: vlada_zaznamy\1993\1993-12-22.doc
# Found link: ../0/DBC52BAFEF375EFFC12571B6007071D4
# ✅ Downloaded: vlada_zaznamy\1993\1993-12-15.doc
# Found link: ../0/E06DAC7C6EC986B7C12571B6006CD4A6
# ✅ Downloaded: vlada_zaznamy\1993\1993-12-08.doc
# Found link: ../0/AD9EE45C468CE173C12571B60070BE7D
# ✅ Downloaded: vlada_zaznamy\1993\1993-12-01.doc
# Found link: ../0/C8EE277CB162BC9EC12571B6006E32EE
# ✅ Downloaded: vlada_zaznamy\1993\1993-11-24.doc
# Found link: ../0/9496158AB918E35FC12571B6006E95D5
# ✅ Downloaded: vlada_zaznamy\1993\1993-11-17.doc
# Found link: ../0/C046223FC2EDD4F7C12571B6006C43AB
# ✅ Downloaded: vlada_zaznamy\1993\1993-11-10.doc
# Found link: ../0/52021A6A00FF7817C12571B6006AE2D1
# ✅ Downloaded: vlada_zaznamy\1993\1993-11-03.doc
# Found link: ../0/9C1AE0CED0CA3160C12571B6006B5A78
# ✅ Downloaded: vlada_zaznamy\1993\1993-10-27.doc
# Found link: ../0/E59C057BF5ACE367C12571B6006D70C7
# ✅ Downloaded: vlada_zaznamy\1993\1993-10-20.doc
# Found link: ../0/1ADC4E889F98D460C12571B6006E1D50
# ✅ Downloaded: vlada_zaznamy\1993\1993-10-13.doc
# Found link: ../0/23059B95B4956A99C12571B6006DF0ED
# ✅ Downloaded: vlada_zaznamy\1993\1993-10-06.doc
# Found link: ../0/37AFBAD6252816A4C12571B6006DC5B8
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-29.doc
# Found link: ../0/BE8A45F34A4FE9D6C12571B6006D4106
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-24.doc
# Found link: ../0/D05BAE01FE46192EC12571B6006D680D
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-22.doc
# Found link: ../0/72D7AA6ABFD17A85C12571B6006C5343
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-15.doc
# Found link: ../0/DD3FC6E3B2C76C0EC12571B6006B314F
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-08.doc
# Found link: ../0/EC3F3AE2703DC095C12571B6006E577F
# ✅ Downloaded: vlada_zaznamy\1993\1993-09-01.doc
# Found link: ../0/EBB7346988C1A363C12571B600708785
# ✅ Downloaded: vlada_zaznamy\1993\1993-08-25.doc
# Found link: ../0/DF9C94E9813EFAB1C12571B6006F7EDD
# ✅ Downloaded: vlada_zaznamy\1993\1993-08-18.doc
# Found link: ../0/1844345BE6D8B3A6C12571B6006FD5E3
# ✅ Downloaded: vlada_zaznamy\1993\1993-08-11.doc
# Found link: ../0/D749701962FBB903C12571B6006B031B
# ✅ Downloaded: vlada_zaznamy\1993\1993-07-21.doc
# Found link: ../0/E46080BB2766832AC12571B6006E8A1B
# ✅ Downloaded: vlada_zaznamy\1993\1993-07-14.doc
# Found link: ../0/396EC3E442EC51F3C12571B6006ED791
# ✅ Downloaded: vlada_zaznamy\1993\1993-07-07.doc
# Found link: ../0/E1A56EF8729CB346C12571B6006CD94F
# ✅ Downloaded: vlada_zaznamy\1993\1993-06-30.doc
# Found link: ../0/5405A06F238987A3C12571B6006D2E28
# ✅ Downloaded: vlada_zaznamy\1993\1993-06-23.doc
# Found link: ../0/7473EBF1CD9861B5C12571B6006BEABA
# ✅ Downloaded: vlada_zaznamy\1993\1993-06-16.doc
# Found link: ../0/56CED0CCA27D4CD8C12571B6006FDEAA
# ✅ Downloaded: vlada_zaznamy\1993\1993-06-09.doc
# Found link: ../0/B6320088528263B6C12571B6007043F9
# ✅ Downloaded: vlada_zaznamy\1993\1993-06-02.doc
# Found link: ../0/4225C70ABF3F7513C12571B6006E0B4D
# ✅ Downloaded: vlada_zaznamy\1993\1993-05-26.doc
# Found link: ../0/97AF96CACD7FD134C12571B6006C1FF8
# ✅ Downloaded: vlada_zaznamy\1993\1993-05-19.doc
# Found link: ../0/AB9E73BFE6E82AA7C12571B60070EA56
# ✅ Downloaded: vlada_zaznamy\1993\1993-05-12.doc
# Found link: ../0/DA12A629081EDAEFC12571B60070E3CB
# ✅ Downloaded: vlada_zaznamy\1993\1993-05-05.doc
# Found link: ../0/43E44EEFD385CE30C12571B6006BF557
# ✅ Downloaded: vlada_zaznamy\1993\1993-04-28.doc
# Found link: ../0/A6EE4EEA6922E9A4C12571B6006B0C74
# ✅ Downloaded: vlada_zaznamy\1993\1993-04-21.doc
# Found link: ../0/94265DA38D8680F7C12571B6006BD99D
# ✅ Downloaded: vlada_zaznamy\1993\1993-04-14.doc
# Found link: ../0/7D2A4DCB2BAF3D07C12571B6006DA42D
# ✅ Downloaded: vlada_zaznamy\1993\1993-04-07.doc
# Found link: ../0/D38D96147227F6E5C12571B6006DDB98
# ✅ Downloaded: vlada_zaznamy\1993\1993-03-31.doc
# Found link: ../0/94948D2B8E269571C12571B6006BC1A9
# ✅ Downloaded: vlada_zaznamy\1993\1993-03-24.doc
# Found link: ../0/E60314C6C5C99055C12571B6006FA6AF
# ✅ Downloaded: vlada_zaznamy\1993\1993-03-17.doc
# Found link: ../0/C9B0F1B376C5C314C12571B6006F06A0
# ✅ Downloaded: vlada_zaznamy\1993\1993-03-10.doc
# Found link: ../0/12F02863AB0F0866C12571B6006E47D7
# ✅ Downloaded: vlada_zaznamy\1993\1993-03-03.doc
# Found link: ../0/7555F168A84DD996C12571B6006DDFF6
# ✅ Downloaded: vlada_zaznamy\1993\1993-02-24.doc
# Found link: ../0/2AB6B428116A107BC12571B6006DC575
# ✅ Downloaded: vlada_zaznamy\1993\1993-02-17.doc
# Found link: ../0/1886A614F6487F47C12571B6006BDEE3
# ✅ Downloaded: vlada_zaznamy\1993\1993-02-10.doc
# Found link: ../0/D32C6BA8B9C1AD58C12571B6006BF3D4
# ✅ Downloaded: vlada_zaznamy\1993\1993-02-04.doc
# Found link: ../0/70CCF688E16DE39FC12571B6006E9897
# ✅ Downloaded: vlada_zaznamy\1993\1993-02-03.doc
# Found link: ../0/2E8F765E4DBEFD36C12571B6006EE8B5
# ✅ Downloaded: vlada_zaznamy\1993\1993-01-27.doc
# Found link: ../0/A668004CE53081A1C12571B6006E9136
# ✅ Downloaded: vlada_zaznamy\1993\1993-01-20.doc
# Found link: ../0/A2192596619EFCE3C12571B6006D4A55
# ✅ Downloaded: vlada_zaznamy\1993\1993-01-13.doc
# Found link: ../0/89C76A97DE379E02C12571B600703590
# ✅ Downloaded: vlada_zaznamy\1993\1993-01-06.doc
#
# 📅 Year 1994
# Found 51 meetings
# Found link: ../0/947887F8AC1BF01AC12571B6006E8A74
# ✅ Downloaded: vlada_zaznamy\1994\1994-12-21.doc
# Found link: ../0/E17AA882C0923FE4C12571B6006E88D3
# ✅ Downloaded: vlada_zaznamy\1994\1994-12-19.doc
# Found link: ../0/CE007B3E67FCB7DBC12571B600708E27
# ✅ Downloaded: vlada_zaznamy\1994\1994-12-14.doc
# Found link: ../0/1E6411DAD8A881CCC12571B6006D800B
# ✅ Downloaded: vlada_zaznamy\1994\1994-12-07.doc
# Found link: ../0/CFCFD7BB4A67D39AC12571B6006FD39B
# ✅ Downloaded: vlada_zaznamy\1994\1994-11-30.doc
# Found link: ../0/130F3C7A07221B62C12571B6006E3B09
# ✅ Downloaded: vlada_zaznamy\1994\1994-11-23.doc
# Found link: ../0/6562E17DD62275A9C12571B6006C5916
# ✅ Downloaded: vlada_zaznamy\1994\1994-11-16.doc
# Found link: ../0/8C0AAD58C2782FC0C12571B6006AFA75
# ✅ Downloaded: vlada_zaznamy\1994\1994-11-09.doc
# Found link: ../0/9841440B352AB31CC12571B6006DEDFC
# ✅ Downloaded: vlada_zaznamy\1994\1994-11-02.doc
# Found link: ../0/C48F4D82A9AF6154C12571B6006CA8DF
# ✅ Downloaded: vlada_zaznamy\1994\1994-10-26.doc
# Found link: ../0/E852AA7266FD4F62C12571B6006D05B1
# ✅ Downloaded: vlada_zaznamy\1994\1994-10-19.doc
# Found link: ../0/63D326BF8BB22579C12571B60070CBB5
# ✅ Downloaded: vlada_zaznamy\1994\1994-10-12.doc
# Found link: ../0/0D9396B98CBD2E0FC12571B6006E9986
# ✅ Downloaded: vlada_zaznamy\1994\1994-10-05.doc
# Found link: ../0/6F4A7BBB53F72535C12571B60070EC55
# ✅ Downloaded: vlada_zaznamy\1994\1994-09-28.doc
# Found link: ../0/6301F9C5E0BA646FC12571B6006E4E78
# ✅ Downloaded: vlada_zaznamy\1994\1994-09-21.doc
# Found link: ../0/F5C7E8D714CA429EC12571B6006FEEA5
# ✅ Downloaded: vlada_zaznamy\1994\1994-09-14.doc
# Found link: ../0/B7BB6B77E7EE0214C12571B600707559
# ✅ Downloaded: vlada_zaznamy\1994\1994-09-07.doc
# Found link: ../0/58D528A53A1E5739C12571B6006ED708
# ✅ Downloaded: vlada_zaznamy\1994\1994-08-31.doc
# Found link: ../0/73206E26C6993BFBC12571B6006FA071
# ✅ Downloaded: vlada_zaznamy\1994\1994-08-24.doc
# Found link: ../0/0BAF9F873A6BA744C12571B600709702
# ✅ Downloaded: vlada_zaznamy\1994\1994-08-17.doc
# Found link: ../0/26E383D0116B6CBBC12571B6006FF96E
# ✅ Downloaded: vlada_zaznamy\1994\1994-08-10.doc
# Found link: ../0/2B1D7B9387E712C4C12571B6006FC3AA
# ✅ Downloaded: vlada_zaznamy\1994\1994-08-03.doc
# Found link: ../0/D8039987F0D63B73C12571B6006D0E3E
# ✅ Downloaded: vlada_zaznamy\1994\1994-07-13.doc
# Found link: ../0/C547A9572B51F652C12571B6006BEB52
# ✅ Downloaded: vlada_zaznamy\1994\1994-07-04.doc
# Found link: ../0/574D8F8FD64652C3C12571B6006CF5EC
# ✅ Downloaded: vlada_zaznamy\1994\1994-06-29.doc
# Found link: ../0/469BEE66450D426FC12571B6006C7F65
# ✅ Downloaded: vlada_zaznamy\1994\1994-06-22.doc
# Found link: ../0/2733AD1EEA005D74C12571B600708C2D
# ✅ Downloaded: vlada_zaznamy\1994\1994-06-15.doc
# Found link: ../0/3C5B75E7386B1461C12571B6006D9F9F
# ✅ Downloaded: vlada_zaznamy\1994\1994-06-08.doc
# Found link: ../0/FE114424705E8F9BC12571B6006C407B
# ✅ Downloaded: vlada_zaznamy\1994\1994-06-01.doc
# Found link: ../0/BA7E1A29BCA4CCB5C12571B6006FBD4E
# ✅ Downloaded: vlada_zaznamy\1994\1994-05-25.doc
# Found link: ../0/71B1521F20075F7AC12571B6006C28A1
# ✅ Downloaded: vlada_zaznamy\1994\1994-05-18.doc
# Found link: ../0/004066FF29060288C12571B6007075D3
# ✅ Downloaded: vlada_zaznamy\1994\1994-05-11.doc
# Found link: ../0/DB911F3D94660A16C12571B6006E00B3
# ✅ Downloaded: vlada_zaznamy\1994\1994-05-04.doc
# Found link: ../0/231CACD4873D59B3C12571B6006D417A
# ✅ Downloaded: vlada_zaznamy\1994\1994-04-27.doc
# Found link: ../0/CDCFF39DDF09DF4AC12571B600702C5B
# ✅ Downloaded: vlada_zaznamy\1994\1994-04-20.doc
# Found link: ../0/42F2BFAADBA25625C12571B6006BB96B
# ✅ Downloaded: vlada_zaznamy\1994\1994-04-13.doc
# Found link: ../0/D731619FA14E8593C12571B6006FF706
# ✅ Downloaded: vlada_zaznamy\1994\1994-04-06.doc
# Found link: ../0/0689114DD138476DC12571B6006C8BB0
# ✅ Downloaded: vlada_zaznamy\1994\1994-04-01.doc
# Found link: ../0/8E080B0CBFA23D4BC12571B6006F2C1A
# ✅ Downloaded: vlada_zaznamy\1994\1994-03-30.doc
# Found link: ../0/CB8585CC4446B0E5C12571B6006C33C9
# ✅ Downloaded: vlada_zaznamy\1994\1994-03-23.doc
# Found link: ../0/311BA3FCFE3D0374C12571B6006D687D
# ✅ Downloaded: vlada_zaznamy\1994\1994-03-16.doc
# Found link: ../0/98D65323995D6652C12571B6006BD150
# ✅ Downloaded: vlada_zaznamy\1994\1994-03-09.doc
# Found link: ../0/2BFB46B19A94F76DC12571B6006AF664
# ✅ Downloaded: vlada_zaznamy\1994\1994-03-02.doc
# Found link: ../0/E8C0BF5A3224AE62C12571B6006D5008
# ✅ Downloaded: vlada_zaznamy\1994\1994-02-23.doc
# Found link: ../0/89219A70C803202FC12571B6006D691D
# ✅ Downloaded: vlada_zaznamy\1994\1994-02-16.doc
# Found link: ../0/04645AD16A70C0C3C12571B6006BB0DA
# ✅ Downloaded: vlada_zaznamy\1994\1994-02-09.doc
# Found link: ../0/555ADFBFAF86F562C12571B6006CE956
# ✅ Downloaded: vlada_zaznamy\1994\1994-02-02.doc
# Found link: ../0/60EB404E558AC78AC12571B6006F2A9B
# ✅ Downloaded: vlada_zaznamy\1994\1994-01-26.doc
# Found link: ../0/743FD5413131F614C12571B6006C3936
# ✅ Downloaded: vlada_zaznamy\1994\1994-01-19.doc
# Found link: ../0/86CC2B60FCF614F8C12571B6006D5DF3
# ✅ Downloaded: vlada_zaznamy\1994\1994-01-13.doc
# Found link: ../0/C696E8E4FA685B53C12571B6006D5956
# ✅ Downloaded: vlada_zaznamy\1994\1994-01-05.doc
#
# 📅 Year 1995
# Found 49 meetings
# Found link: ../0/1EBB4467F5865526C12571B6006C423D
# ✅ Downloaded: vlada_zaznamy\1995\1995-12-20.doc
# Found link: ../0/A54FCF4E2F3C0672C12571B6006F60F2
# ✅ Downloaded: vlada_zaznamy\1995\1995-12-13.doc
# Found link: ../0/5E8D883359B69591C12571B6006DA371
# ✅ Downloaded: vlada_zaznamy\1995\1995-12-06.doc
# Found link: ../0/2EB61C51AB4ABFE6C12571B60070F838
# ✅ Downloaded: vlada_zaznamy\1995\1995-11-29.doc
# Found link: ../0/B829EF4A5CB94630C12571B6006CB41A
# ✅ Downloaded: vlada_zaznamy\1995\1995-11-22.doc
# Found link: ../0/D457AF4B73EF0788C12571B6006BC446
# ✅ Downloaded: vlada_zaznamy\1995\1995-11-15.doc
# Found link: ../0/3A4534AC52B0ACC5C12571B6006D38AB
# ✅ Downloaded: vlada_zaznamy\1995\1995-11-08.doc
# Found link: ../0/8DF2B52AA810B6F2C12571B60070FDAA
# ✅ Downloaded: vlada_zaznamy\1995\1995-11-01.doc
# Found link: ../0/7DAB4699D082DF65C12571B6006BE61D
# ✅ Downloaded: vlada_zaznamy\1995\1995-10-25.doc
# Found link: ../0/51AED26DD3C0F4DBC12571B600708A4C
# ✅ Downloaded: vlada_zaznamy\1995\1995-10-18.doc
# Found link: ../0/138C5FB35A968EE4C12571B600709666
# ✅ Downloaded: vlada_zaznamy\1995\1995-10-11.doc
# Found link: ../0/3BD346DCA7F376F0C12571B6006CE5FA
# ✅ Downloaded: vlada_zaznamy\1995\1995-10-04.doc
# Found link: ../0/C4C18CC204F0FD55C12571B60070F882
# ✅ Downloaded: vlada_zaznamy\1995\1995-09-27.doc
# Found link: ../0/15286EA5BF32ADB7C12571B6006BBE2A
# ✅ Downloaded: vlada_zaznamy\1995\1995-09-20.doc
# Found link: ../0/417548EF6D322480C12571B6006CCBF2
# ✅ Downloaded: vlada_zaznamy\1995\1995-09-13.doc
# Found link: ../0/98F27C2E4E6020C3C12571B600707E7F
# ✅ Downloaded: vlada_zaznamy\1995\1995-09-06.doc
# Found link: ../0/3D753C0B2E508501C12571B6006C534B
# ✅ Downloaded: vlada_zaznamy\1995\1995-08-30.doc
# Found link: ../0/6C4F79C438C91AC6C12571B6006FB1C9
# ✅ Downloaded: vlada_zaznamy\1995\1995-08-23.doc
# Found link: ../0/ECDCA3CB143C8134C12571B6006EE688
# ✅ Downloaded: vlada_zaznamy\1995\1995-08-16.doc
# Found link: ../0/B12601C957CA8091C12571B6006E7D3B
# ✅ Downloaded: vlada_zaznamy\1995\1995-08-09.doc
# Found link: ../0/48CDB234D2C3097DC12571B6006C4B6E
# ✅ Downloaded: vlada_zaznamy\1995\1995-07-12.doc
# Found link: ../0/32B0F042528FA0F0C12571B6006E847B
# ✅ Downloaded: vlada_zaznamy\1995\1995-07-07.doc
# Found link: ../0/DCBC14C8BAA87EB4C12571B6006D9C82
# ✅ Downloaded: vlada_zaznamy\1995\1995-06-28.doc
# Found link: ../0/16A7E40ED9A63E33C12571B60070D6AE
# ✅ Downloaded: vlada_zaznamy\1995\1995-06-21.doc
# Found link: ../0/A3F2CBCDAB98EE4CC12571B6006D2E40
# ✅ Downloaded: vlada_zaznamy\1995\1995-06-14.doc
# Found link: ../0/D7F22D1A0F8E408DC12571B6006BF089
# ✅ Downloaded: vlada_zaznamy\1995\1995-06-07.doc
# Found link: ../0/E46EF39C9864D37BC12571B6006F90FF
# ✅ Downloaded: vlada_zaznamy\1995\1995-05-31.doc
# Found link: ../0/3D53B66F390130C0C12571B60070B77C
# ✅ Downloaded: vlada_zaznamy\1995\1995-05-24.doc
# Found link: ../0/6302898534B2A2C2C12571B6007047FE
# ✅ Downloaded: vlada_zaznamy\1995\1995-05-17.doc
# Found link: ../0/B5565DC1C5E2E233C12571B60070043D
# ✅ Downloaded: vlada_zaznamy\1995\1995-05-10.doc
# Found link: ../0/E0F4C4523F84737AC12571B60070EBDE
# ✅ Downloaded: vlada_zaznamy\1995\1995-05-03.doc
# Found link: ../0/66E4537895C94A24C12571B6006BAD18
# ✅ Downloaded: vlada_zaznamy\1995\1995-04-28.doc
# Found link: ../0/77E17D63C5B9B09CC12571B6006D9C5E
# ✅ Downloaded: vlada_zaznamy\1995\1995-04-26.doc
# Found link: ../0/55BC51FE84114BD1C12571B6007081C0
# ✅ Downloaded: vlada_zaznamy\1995\1995-04-19.doc
# Found link: ../0/14460530A7AA2677C12571B6006BC54E
# ✅ Downloaded: vlada_zaznamy\1995\1995-04-12.doc
# Found link: ../0/2E3ECFE8F62D995EC12571B6006FDF11
# ✅ Downloaded: vlada_zaznamy\1995\1995-04-05.doc
# Found link: ../0/063B64B51B2023B1C12571B6006E026B
# ✅ Downloaded: vlada_zaznamy\1995\1995-03-29.doc
# Found link: ../0/28E8685793E3A009C12571B6006BB91E
# ✅ Downloaded: vlada_zaznamy\1995\1995-03-22.doc
# Found link: ../0/26C616EFD8168868C12571B6006C2186
# ✅ Downloaded: vlada_zaznamy\1995\1995-03-15.doc
# Found link: ../0/370E9B4B8DEC6E6EC12571B6006F5A41
# ✅ Downloaded: vlada_zaznamy\1995\1995-03-08.doc
# Found link: ../0/1163DC7E19D09027C12571B60070D121
# ✅ Downloaded: vlada_zaznamy\1995\1995-03-01.doc
# Found link: ../0/354ECAFA7CE4258AC12571B6006EB34E
# ✅ Downloaded: vlada_zaznamy\1995\1995-02-22.doc
# Found link: ../0/A867C011EAC2BE1CC12571B6006E2B0A
# ✅ Downloaded: vlada_zaznamy\1995\1995-02-15.doc
# Found link: ../0/05D1BA181271A385C12571B6006FC136
# ✅ Downloaded: vlada_zaznamy\1995\1995-02-08.doc
# Found link: ../0/34854457603A24B8C12571B6006E92BB
# ✅ Downloaded: vlada_zaznamy\1995\1995-02-01.doc
# Found link: ../0/C04F3137CC12E5E1C12571B6006F500E
# ✅ Downloaded: vlada_zaznamy\1995\1995-01-25.doc
# Found link: ../0/6B701BAEB7C67922C12571B600703CB1
# ✅ Downloaded: vlada_zaznamy\1995\1995-01-18.doc
# Found link: ../0/39A160042F2DDD08C12571B6006D37D2
# ✅ Downloaded: vlada_zaznamy\1995\1995-01-11.doc
# Found link: ../0/3868DF1E4347C458C12571B6006D5B35
# ✅ Downloaded: vlada_zaznamy\1995\1995-01-04.doc
#
# 📅 Year 1996
# Found 49 meetings
# Found link: ../0/A83128A93B7E14A3C12571B6006D7B72
# ✅ Downloaded: vlada_zaznamy\1996\1996-12-23.doc
# Found link: ../0/3664B27DB18A1640C12571B6006CC21A
# ✅ Downloaded: vlada_zaznamy\1996\1996-12-17.doc
# Found link: ../0/06816C57C7C8DB5EC12571B6006D88A1
# ✅ Downloaded: vlada_zaznamy\1996\1996-12-11.doc
# Found link: ../0/194FC5C6071E6D70C12571B6007032A3
# ✅ Downloaded: vlada_zaznamy\1996\1996-12-04.doc
# Found link: ../0/79B6E9EE0BD4F7DFC12571B6006D1BDA
# ✅ Downloaded: vlada_zaznamy\1996\1996-11-27.doc
# Found link: ../0/A0F166B69C19540CC12571B6006FD181
# ✅ Downloaded: vlada_zaznamy\1996\1996-11-20.doc
# Found link: ../0/0266479234ACE416C12571B6006F73ED
# ✅ Downloaded: vlada_zaznamy\1996\1996-11-13.doc
# Found link: ../0/50C191167AE838F0C12571B6006C1D98
# ✅ Downloaded: vlada_zaznamy\1996\1996-11-01.doc
# Found link: ../0/E2FE29156B0145FAC12571B6006BA903
# ✅ Downloaded: vlada_zaznamy\1996\1996-10-30.doc
# Found link: ../0/8C8320AB69D89B7BC12571B600704CB1
# ✅ Downloaded: vlada_zaznamy\1996\1996-10-23.doc
# Found link: ../0/29556B81E735584EC12571B6006C419E
# ✅ Downloaded: vlada_zaznamy\1996\1996-10-16.doc
# Found link: ../0/939CF7BBF2281BAAC12571B6006DA6C7
# ✅ Downloaded: vlada_zaznamy\1996\1996-10-10.doc
# Found link: ../0/89E9ECF3681DC971C12571B6006BC7D0
# ✅ Downloaded: vlada_zaznamy\1996\1996-10-02.doc
# Found link: ../0/B2B2B1358BD0937CC12571B6006DDBE5
# ✅ Downloaded: vlada_zaznamy\1996\1996-09-25.doc
# Found link: ../0/AEBB5C9E555D3B2DC12571B6006D111C
# ✅ Downloaded: vlada_zaznamy\1996\1996-09-18.doc
# Found link: ../0/E67886628DDF9246C12571B6006E8166
# ✅ Downloaded: vlada_zaznamy\1996\1996-09-17.doc
# Found link: ../0/F25A1B4BABAD3302C12571B6006D56F1
# ✅ Downloaded: vlada_zaznamy\1996\1996-09-11.doc
# Found link: ../0/7FF549C52F9D22AAC12571B6006F83F6
# ✅ Downloaded: vlada_zaznamy\1996\1996-09-04.doc
# Found link: ../0/021B0025963510E5C12571B6006D0CFF
# ✅ Downloaded: vlada_zaznamy\1996\1996-08-28.doc
# Found link: ../0/5D2D08910FC19A4DC12571B6006E2E73
# ✅ Downloaded: vlada_zaznamy\1996\1996-08-21.doc
# Found link: ../0/0A790B9775AD23C4C12571B6006E1318
# ✅ Downloaded: vlada_zaznamy\1996\1996-08-14.doc
# Found link: ../0/8C8F7FE1B8F627DBC12571B6006D8401
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-23.doc
# Found link: ../0/F250ACFB65454F6EC12571B6006F8CC0
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-17.doc
# Found link: ../0/57E4813401E81357C12571B6006B997D
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-12.doc
# Found link: ../0/71D980AA6BB00D53C12571B6006F6E62
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-10.doc
# Found link: ../0/4F6AFCBC92BB5398C12571B600708FF7
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-04.doc
# Found link: ../0/54552A40A0C6F75BC12571B60070E233
# ✅ Downloaded: vlada_zaznamy\1996\1996-07-01.doc
# Found link: ../0/3971FD670CFF9570C12571B6007060B3
# ✅ Downloaded: vlada_zaznamy\1996\1996-06-19.doc
# Found link: ../0/EFB70793AE0C804AC12571B6006F6ED5
# ✅ Downloaded: vlada_zaznamy\1996\1996-06-12.doc
# Found link: ../0/76F86FE0F0877D4DC12571B6006D3F6E
# ✅ Downloaded: vlada_zaznamy\1996\1996-06-05.doc
# Found link: ../0/36F60C231CB32B9AC12571B6006BF675
# ✅ Downloaded: vlada_zaznamy\1996\1996-05-30.doc
# Found link: ../0/1AA6FB71D0FF18BDC12571B6006D8FF4
# ✅ Downloaded: vlada_zaznamy\1996\1996-05-15.doc
# Found link: ../0/C5E25807B3656837C12571B6006DF81C
# ✅ Downloaded: vlada_zaznamy\1996\1996-05-09.doc
# Found link: ../0/ABF6F9B2C22EF0A1C12571B600704355
# ✅ Downloaded: vlada_zaznamy\1996\1996-05-02.doc
# Found link: ../0/FCE6E73013F1E482C12571B6006C3252
# ✅ Downloaded: vlada_zaznamy\1996\1996-04-24.doc
# Found link: ../0/5E00BF2BFBAC7D80C12571B60070BEFB
# ✅ Downloaded: vlada_zaznamy\1996\1996-04-10.doc
# Found link: ../0/AA323F2C4FA28A34C12571B6006CE572
# ✅ Downloaded: vlada_zaznamy\1996\1996-04-03.doc
# Found link: ../0/0CB255F8F4B974BBC12571B6006B0AC0
# ✅ Downloaded: vlada_zaznamy\1996\1996-03-27.doc
# Found link: ../0/4FB8835450C214A5C12571B6006F5D08
# ✅ Downloaded: vlada_zaznamy\1996\1996-03-20.doc
# Found link: ../0/977B544A9B93CC6AC12571B60070D707
# ✅ Downloaded: vlada_zaznamy\1996\1996-03-06.doc
# Found link: ../0/C1B91F1E1164AE7FC12571B6006F8229
# ✅ Downloaded: vlada_zaznamy\1996\1996-02-28.doc
# Found link: ../0/1FA545D57D5F5A9BC12571B6006C03FC
# ✅ Downloaded: vlada_zaznamy\1996\1996-02-21.doc
# Found link: ../0/06C24E9C8FFACAE0C12571B6006F2BA3
# ✅ Downloaded: vlada_zaznamy\1996\1996-02-14.doc
# Found link: ../0/14F9AE3ABAD9F288C12571B6006C259B
# ✅ Downloaded: vlada_zaznamy\1996\1996-02-07.doc
# Found link: ../0/29DBB109792F0B57C12571B6006AE760
# ✅ Downloaded: vlada_zaznamy\1996\1996-01-31.doc
# Found link: ../0/4192214AADD33ED7C12571B6006E3E8A
# ✅ Downloaded: vlada_zaznamy\1996\1996-01-24.doc
# Found link: ../0/CF0D2405D38FC3D7C12571B6006BB16A
# ✅ Downloaded: vlada_zaznamy\1996\1996-01-17.doc
# Found link: ../0/0C0E59B5102BFCABC12571B6006B1EA5
# ✅ Downloaded: vlada_zaznamy\1996\1996-01-12.doc
# Found link: ../0/08276F0245990F8AC12571B6006E4DD4
# ✅ Downloaded: vlada_zaznamy\1996\1996-01-03.doc
#
# 📅 Year 1997
# Found 51 meetings
# Found link: ../0/9FA1CC9DACB67F80C12571B6006B28BF
# ✅ Downloaded: vlada_zaznamy\1997\1997-12-17.doc
# Found link: ../0/418D479A56A33B9FC12571B6006C1D69
# ✅ Downloaded: vlada_zaznamy\1997\1997-12-10.doc
# Found link: ../0/7982705D70BB1AB0C12571B6006C225E
# ✅ Downloaded: vlada_zaznamy\1997\1997-12-03.doc
# Found link: ../0/075C712971F1D10BC12571B6006EDC2E
# ✅ Downloaded: vlada_zaznamy\1997\1997-11-26.doc
# Found link: ../0/F8EE7088048C0799C12571B6006C9211
# ✅ Downloaded: vlada_zaznamy\1997\1997-11-19.doc
# Found link: ../0/7F60568EFAD7717FC12571B6006C2359
# ✅ Downloaded: vlada_zaznamy\1997\1997-11-12.doc
# Found link: ../0/4AC3EA08AB8E1BB3C12571B6006B419E
# ✅ Downloaded: vlada_zaznamy\1997\1997-11-05.doc
# Found link: ../0/2D9AD57C26F94E64C12571B600703DEB
# ✅ Downloaded: vlada_zaznamy\1997\1997-10-29.doc
# Found link: ../0/8292A207AF5365A1C12571B6006CB72D
# ✅ Downloaded: vlada_zaznamy\1997\1997-10-22.doc
# Found link: ../0/F7332A52D9742CA5C12571B6006CDD3D
# ✅ Downloaded: vlada_zaznamy\1997\1997-10-15.doc
# Found link: ../0/17D4D6D4020793B9C12571B6006CE440
# ✅ Downloaded: vlada_zaznamy\1997\1997-10-08.doc
# Found link: ../0/586B32B753DB2DD8C12571B6006EB7A2
# ✅ Downloaded: vlada_zaznamy\1997\1997-10-01.doc
# Found link: ../0/D47B7E74C8C05D67C12571B6006ED6B3
# ✅ Downloaded: vlada_zaznamy\1997\1997-09-25.doc
# Found link: ../0/1273EE1A688D7A24C12571B6006D7EED
# ✅ Downloaded: vlada_zaznamy\1997\1997-09-17.doc
# Found link: ../0/7BE6B3D62A6E9F86C12571B6006FA9BC
# ✅ Downloaded: vlada_zaznamy\1997\1997-09-10.doc
# Found link: ../0/CA7CB4EDED3A3597C12571B6006BA60B
# ✅ Downloaded: vlada_zaznamy\1997\1997-09-03.doc
# Found link: ../0/E19F465BC0D08639C12571B6006BA6D6
# ✅ Downloaded: vlada_zaznamy\1997\1997-08-27.doc
# Found link: ../0/37601CD774F69481C12571B6006F9CC9
# ✅ Downloaded: vlada_zaznamy\1997\1997-08-20.doc
# Found link: ../0/1D913BC06295F788C12571B6006C554E
# ✅ Downloaded: vlada_zaznamy\1997\1997-08-13.doc
# Found link: ../0/0DFE517D39849C02C12571B600701090
# ✅ Downloaded: vlada_zaznamy\1997\1997-07-23.doc
# Found link: ../0/E99D7236E2335E40C12571B600702F97
# ✅ Downloaded: vlada_zaznamy\1997\1997-07-16.doc
# Found link: ../0/9D2DF8DC5BBBDD97C12571B600709F99
# ✅ Downloaded: vlada_zaznamy\1997\1997-07-10.doc
# Found link: ../0/36F8457C27DE3091C12571B6006D8FFF
# ✅ Downloaded: vlada_zaznamy\1997\1997-07-09.doc
# Found link: ../0/0A3FA1B0957E88CFC12571B6006C50EE
# ✅ Downloaded: vlada_zaznamy\1997\1997-07-02.doc
# Found link: ../0/CF3B3D3C9BCB27EDC12571B6006D1CB4
# ✅ Downloaded: vlada_zaznamy\1997\1997-06-25.doc
# Found link: ../0/4CB8BA5DB72EDD6DC12571B6006BC29A
# ✅ Downloaded: vlada_zaznamy\1997\1997-06-18.doc
# Found link: ../0/6B25574E679DC142C12571B6006BEB47
# ✅ Downloaded: vlada_zaznamy\1997\1997-06-12.doc
# Found link: ../0/9E7A4F84161DEC10C12571B6006CFC51
# ✅ Downloaded: vlada_zaznamy\1997\1997-06-09.doc
# Found link: ../0/DD865F98A4E7D946C12571B6006CB001
# ✅ Downloaded: vlada_zaznamy\1997\1997-06-04.doc
# Found link: ../0/CEC8A9A9E258D958C12571B6006F7272
# ✅ Downloaded: vlada_zaznamy\1997\1997-05-21.doc
# Found link: ../0/CCAD365FC8809E9DC12571B6006B98A4
# ✅ Downloaded: vlada_zaznamy\1997\1997-05-14.doc
# Found link: ../0/DD63D8ACCE70BAC1C12571B6006E1C2D
# ✅ Downloaded: vlada_zaznamy\1997\1997-05-07.doc
# Found link: ../0/A67FFF376C346CEAC12571B6006EB288
# ✅ Downloaded: vlada_zaznamy\1997\1997-04-30.doc
# Found link: ../0/D2FD823606E13D7DC12571B6006CB85B
# ✅ Downloaded: vlada_zaznamy\1997\1997-04-23.doc
# Found link: ../0/D8A7DE1B8FECDC08C12571B6006B7A18
# ✅ Downloaded: vlada_zaznamy\1997\1997-04-16.doc
# Found link: ../0/EE8DCCF60FDD29E4C12571B6006E28EC
# ✅ Downloaded: vlada_zaznamy\1997\1997-04-09.doc
# Found link: ../0/02BEEE4027B504D1C12571B6006F8E72
# ✅ Downloaded: vlada_zaznamy\1997\1997-04-02.doc
# Found link: ../0/0937AA8180E9C683C12571B6007086EA
# ✅ Downloaded: vlada_zaznamy\1997\1997-03-26.doc
# Found link: ../0/5705FFB12CA01ACBC12571B60070EF0D
# ✅ Downloaded: vlada_zaznamy\1997\1997-03-19.doc
# Found link: ../0/06E13BBC6B7D914DC12571B60070082B
# ✅ Downloaded: vlada_zaznamy\1997\1997-03-12.doc
# Found link: ../0/F281021659A68E03C12571B6006D2382
# ✅ Downloaded: vlada_zaznamy\1997\1997-03-05.doc
# Found link: ../0/551EFE78DB304137C12571B6006C0101
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-28.doc
# Found link: ../0/D99A89690CEF8391C12571B6006E8426
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-26.doc
# Found link: ../0/FE3CEE8F2283ACFAC12571B6006DC090
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-19.doc
# Found link: ../0/37AE7B242A7F1BF9C12571B6006CAF38
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-13.doc
# Found link: ../0/FB57AF217AE1EC38C12571B6006CEBCA
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-12.doc
# Found link: ../0/0220666B05CCEE42C12571B6006AF66D
# ✅ Downloaded: vlada_zaznamy\1997\1997-02-05.doc
# Found link: ../0/4E54FC962828E879C12571B6006BFC64
# ✅ Downloaded: vlada_zaznamy\1997\1997-01-29.doc
# Found link: ../0/D6E3B0D4946E30B3C12571B6006D6E00
# ✅ Downloaded: vlada_zaznamy\1997\1997-01-22.doc
# Found link: ../0/81DB84ED5D542EC7C12571B60070BC58
# ✅ Downloaded: vlada_zaznamy\1997\1997-01-15.doc
# Found link: ../0/79811446CC596BE1C12571B6006CE380
# ✅ Downloaded: vlada_zaznamy\1997\1997-01-08.doc
#
# 📅 Year 1998
# Found 60 meetings
# Found link: ../0/1B6205A2CFB5483CC12571B6006CD2CA
# ✅ Downloaded: vlada_zaznamy\1998\1998-12-23.doc
# Found link: ../0/463EA5EB7601D451C12571B6006D9E86
# ✅ Downloaded: vlada_zaznamy\1998\1998-12-16.doc
# Found link: ../0/1F44AF570B69359EC12571B60070B587
# ✅ Downloaded: vlada_zaznamy\1998\1998-12-09.doc
# Found link: ../0/B533B085D6344EEBC12571B6006C2E17
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-30.doc
# Found link: ../0/E78A08617D8C3501C12571B6006C3C79
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-25.doc
# Found link: ../0/D5C81AFC22B05AF5C12571B6006D4918
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-18.doc
# Found link: ../0/E7D94B5A8E56509AC12571B6006F001E
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-11.doc
# Found link: ../0/0AD7EA19C7EE81E9C12571B6006BED14
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-06.doc
# Found link: ../0/361D23FDC6A9C96AC12571B600704BF7
# ✅ Downloaded: vlada_zaznamy\1998\1998-11-04.doc
# Found link: ../0/98999D7050098055C12571B6006EADAE
# ✅ Downloaded: vlada_zaznamy\1998\1998-10-26.doc
# Found link: ../0/02F6E068C8577509C12571B60070C588
# ✅ Downloaded: vlada_zaznamy\1998\1998-10-19.doc
# Found link: ../0/B3AD12D4B78D9563C12571B6006CC7A6
# ✅ Downloaded: vlada_zaznamy\1998\1998-10-12.doc
# Found link: ../0/327A36BDAA8AF907C12571B6006D18A5
# ✅ Downloaded: vlada_zaznamy\1998\1998-10-07.doc
# Found link: ../0/F9C63696B2EE1C3FC12571B6006CA3D2
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-30.doc
# Found link: ../0/982BA00388B38611C12571B6006C057F
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-23.doc
# Found link: ../0/7E486F7233D2C08AC12571B6006CA141
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-22.doc
# Found link: ../0/CF9D806977767399C12571B6006DE78A
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-16.doc
# Found link: ../0/E42C74A0315915EEC12571B60070B277
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-13.doc
# Found link: ../0/816BE6FF4B27EE43C12571B6006FAB8F
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-09.doc
# Found link: ../0/15BE681198DB2CA9C12571B6006D436F
# ✅ Downloaded: vlada_zaznamy\1998\1998-09-02.doc
# Found link: ../0/D861E8C3BF089CFBC12571B6006E0238
# ✅ Downloaded: vlada_zaznamy\1998\1998-08-26.doc
# Found link: ../0/F7C2DDFFDFAFFA96C12571B6006C69CC
# ✅ Downloaded: vlada_zaznamy\1998\1998-08-21.doc
# Found link: ../0/483EEC21231752DCC12571B6006FADA1
# ✅ Downloaded: vlada_zaznamy\1998\1998-08-12.doc
# Found link: ../0/F7BDF5F64A22F769C12571B6006CD85F
# ✅ Downloaded: vlada_zaznamy\1998\1998-08-05.doc
# Found link: ../0/9B720AB0BA6FFFFFC12571B6006F4AA9
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-29.doc
# Found link: ../0/00F26DAAE54252C4C12571B6006CF724
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-24.doc
# Found link: ../0/4FDD178F39810354C12571B6006FC2F3
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-22.doc
# Found link: ../0/48914B2F4829F662C12571B60070F4E8
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-17.doc
# Found link: ../0/919CAD19D73CD82AC12571B6006CEFE4
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-08.doc
# Found link: ../0/BACFF646E3396FD3C12571B6006C802F
# ✅ Downloaded: vlada_zaznamy\1998\1998-07-01.doc
# Found link: ../0/827730D476979A85C12571B6006DD724
# ✅ Downloaded: vlada_zaznamy\1998\1998-06-24.doc
# Found link: ../0/E8D17A7364A7951AC12571B6006E0FF8
# ✅ Downloaded: vlada_zaznamy\1998\1998-06-17.doc
# Found link: ../0/1561F4DA27909BA1C12571B6006B12A6
# ✅ Downloaded: vlada_zaznamy\1998\1998-06-10.doc
# Found link: ../0/B317645C8FD7FEA1C12571B6006F8093
# ✅ Downloaded: vlada_zaznamy\1998\1998-06-03.doc
# Found link: ../0/ADC919C741C7F585C12571B6006ED623
# ✅ Downloaded: vlada_zaznamy\1998\1998-05-27.doc
# Found link: ../0/040646FA04673C8EC12571B6006B01D3
# ✅ Downloaded: vlada_zaznamy\1998\1998-05-19.doc
# Found link: ../0/19478967230BE824C12571B6006EA4F3
# ✅ Downloaded: vlada_zaznamy\1998\1998-05-18.doc
# Found link: ../0/1A89BF98EC4A3B51C12571B6006DF180
# ✅ Downloaded: vlada_zaznamy\1998\1998-05-11.doc
# Found link: ../0/38C34B33AC5AE00CC12571B6006DDEA4
# ✅ Downloaded: vlada_zaznamy\1998\1998-05-06.doc
# Found link: ../0/178B83464DCDB03BC12571B6007062D5
# ✅ Downloaded: vlada_zaznamy\1998\1998-04-29.doc
# Found link: ../0/920F5B40D712B60EC12571B6006EC9B6
# ✅ Downloaded: vlada_zaznamy\1998\1998-04-22.doc
# Found link: ../0/CCD0B09ABBD4BE60C12571B6006ED5E8
# ✅ Downloaded: vlada_zaznamy\1998\1998-04-15.doc
# Found link: ../0/1AF451B0B33028E6C12571B600701E4B
# ✅ Downloaded: vlada_zaznamy\1998\1998-04-14.doc
# Found link: ../0/7682B0BA2ACAE473C12571B6006F847F
# ✅ Downloaded: vlada_zaznamy\1998\1998-04-08.doc
# Found link: ../0/2F99F7340C99AD61C12571B6006AEF25
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-30.doc
# Found link: ../0/1A788494245F49D4C12571B6006BF87C
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-23.doc
# Found link: ../0/443F5936EA7E67A1C12571B6006ECED4
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-18.doc
# Found link: ../0/9EEE7660610342F1C12571B6006FFAE8
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-11.doc
# Found link: ../0/2257C61473C711D7C12571B6006E9C92
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-04.doc
# Found link: ../0/C5B55D588EEE0412C12571B6006F28B2
# ✅ Downloaded: vlada_zaznamy\1998\1998-03-02.doc
# Found link: ../0/81482D9AE4125D80C12571B6006C7720
# ✅ Downloaded: vlada_zaznamy\1998\1998-02-23.doc
# Found link: ../0/33972389AD0E7E34C12571B6006DDCFE
# ✅ Downloaded: vlada_zaznamy\1998\1998-02-18.doc
# Found link: ../0/1E9AA8C8331479A4C12571B6006BE90B
# ✅ Downloaded: vlada_zaznamy\1998\1998-02-09.doc
# Found link: ../0/ADBC02365D6E7294C12571B6006F0211
# ✅ Downloaded: vlada_zaznamy\1998\1998-02-02.doc
# Found link: ../0/0D23FCE17C2835D6C12571B6006DE726
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-29.doc
# Found link: ../0/838B8A96987168EAC12571B6006FCEEE
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-21.doc
# Found link: ../0/AD1E272937182507C12571B6006C2A4F
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-14.doc
# Found link: ../0/816F3CE97DA65215C12571B6006CADDE
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-12.doc
# Found link: ../0/FF8F8467C9140CA9C12571B6006D0B85
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-07.doc
# Found link: ../0/176424890E7700C9C12571B6006D0ABD
# ✅ Downloaded: vlada_zaznamy\1998\1998-01-05.doc
#
# 📅 Year 1999
# Found 58 meetings
# Found link: ../0/3B0931D35D5E4EE0C12571B6006D5ED8
# ✅ Downloaded: vlada_zaznamy\1999\1999-12-22.doc
# Found link: ../0/08025C4331B47778C12571B6006C292C
# ✅ Downloaded: vlada_zaznamy\1999\1999-12-13.doc
# Found link: ../0/D7A959208FC23BF3C12571B6006C28EC
# ✅ Downloaded: vlada_zaznamy\1999\1999-12-06.doc
# Found link: ../0/9FCEFCF0C1F5B3ACC12571B6006FDAEC
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-29.doc
# Found link: ../0/A9E9BEFCCF86FBBEC12571B6006D7BC5
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-22.doc
# Found link: ../0/8C64123DE31BE951C12571B6006D7E36
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-15.doc
# Found link: ../0/9A1990E782A91698C12571B6006E10E7
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-13.doc
# Found link: ../0/EB1F9E14410111E7C12571B6006D5534
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-08.doc
# Found link: ../0/8551EDDBC0A6B5BAC12571B600709C90
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-05.doc
# Found link: ../0/BF912BAC36B5F9B9C12571B6006AFC7B
# ✅ Downloaded: vlada_zaznamy\1999\1999-11-01.doc
# Found link: ../0/CBF7B9AD68A0E2B4C12571B6006CDD54
# ✅ Downloaded: vlada_zaznamy\1999\1999-10-27.doc
# Found link: ../0/B6CBEBB0FFA3EFCFC12571B6006D2044
# ✅ Downloaded: vlada_zaznamy\1999\1999-10-18.doc
# Found link: ../0/CA23F15E6BCA40D0C12571B6006BAC00
# ✅ Downloaded: vlada_zaznamy\1999\1999-10-11.doc
# Found link: ../0/59603C57D5606F21C12571B6006E330C
# ✅ Downloaded: vlada_zaznamy\1999\1999-10-06.doc
# Found link: ../0/DFC62A69B092C00EC12571B6006C4157
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-29.doc
# Found link: ../0/9BCB3F27AA2896E6C12571B600709CAB
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-24.doc
# Found link: ../0/B48DD0C6B474931BC12571B6006D96E0
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-22.doc
# Found link: ../0/B2AC7A5E18C997B3C12571B6006F6B4F
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-20.doc
# Found link: ../0/9AD4AF5ED6AFDA8BC12571B6006C1909
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-15.doc
# Found link: ../0/B739BFF8D632BF17C12571B6006C4657
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-08.doc
# Found link: ../0/B8CF4D2398CFA9D7C12571B6006CDC04
# ✅ Downloaded: vlada_zaznamy\1999\1999-09-01.doc
# Found link: ../0/65A31E6DBBB6B44CC12571B6006E2EFB
# ✅ Downloaded: vlada_zaznamy\1999\1999-08-25.doc
# Found link: ../0/02AF6F83C93434D7C12571B6006E9CE8
# ✅ Downloaded: vlada_zaznamy\1999\1999-07-28.doc
# Found link: ../0/B1AC07172B6330ADC12571B6006D7F43
# ✅ Downloaded: vlada_zaznamy\1999\1999-07-21.doc
# Found link: ../0/ADE7DAF4533C57E3C12571B6006F50F7
# ✅ Downloaded: vlada_zaznamy\1999\1999-07-14.doc
# Found link: ../0/CD55734E0D6E38CDC12571B6006F7BBA
# ✅ Downloaded: vlada_zaznamy\1999\1999-07-07.doc
# Found link: ../0/A9B5724130BA3EC1C12571B6006C87B5
# ✅ Downloaded: vlada_zaznamy\1999\1999-06-28.doc
# Found link: ../0/435D0239F031599AC12571B60070F98A
# ✅ Downloaded: vlada_zaznamy\1999\1999-06-23.doc
# Found link: ../0/006644B13163C6BBC12571B6006E88C4
# ✅ Downloaded: vlada_zaznamy\1999\1999-06-16.doc
# Found link: ../0/2ABF735E5C022B00C12571B6006F2460
# ✅ Downloaded: vlada_zaznamy\1999\1999-06-09.doc
# Found link: ../0/FEB7E5EDF6FA4400C12571B6006AE941
# ✅ Downloaded: vlada_zaznamy\1999\1999-06-08.doc
# Found link: ../0/9666473693E5FCC5C12571B6006E416C
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-31.doc
# Found link: ../0/EC581D997E781CF0C12571B60070CB4E
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-26.doc
# Found link: ../0/1F6D65AE0FDBD4B2C12571B6006F69B4
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-17.doc
# Found link: ../0/2446C0859C8253F5C12571B6006C8EDD
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-12.doc
# Found link: ../0/804B0B516F457586C12571B6006D3DF9
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-10.doc
# Found link: ../0/6A1414BB7E4DEACCC12571B6006BBF93
# ✅ Downloaded: vlada_zaznamy\1999\1999-05-05.doc
# Found link: ../0/6046455F470406BCC12571B600703287
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-28.doc
# Found link: ../0/A9FE775EA33D1199C12571B6006CCF99
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-27.doc
# Found link: ../0/A9A659097E2611E8C12571B6006FDDD1
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-21.doc
# Found link: ../0/2AC9270F6177BBDBC12571B6006E807D
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-19.doc
# Found link: ../0/B80C95BAF27B8619C12571B600707BAF
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-14.doc
# Found link: ../0/0FC59EAD2E9F83A8C12571B6006F37AC
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-11.doc
# Found link: ../0/A6A7DB060E415238C12571B6006D0FE6
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-07.doc
# Found link: ../0/400160E5D775F842C12571B6006DA887
# ✅ Downloaded: vlada_zaznamy\1999\1999-04-02.doc
# Found link: ../0/0846314B03AC105EC12571B6006FC60D
# ✅ Downloaded: vlada_zaznamy\1999\1999-03-29.doc
# Found link: ../0/25EB8EA75D27E85DC12571B6006E070C
# ✅ Downloaded: vlada_zaznamy\1999\1999-03-22.doc
# Found link: ../0/8DCB32F5FFF91BA4C12571B6006E2434
# ✅ Downloaded: vlada_zaznamy\1999\1999-03-17.doc
# Found link: ../0/D612232998CC252CC12571B6006D1470
# ✅ Downloaded: vlada_zaznamy\1999\1999-03-10.doc
# Found link: ../0/D33729C7D2A7F715C12571B6006E931F
# ✅ Downloaded: vlada_zaznamy\1999\1999-03-03.doc
# Found link: ../0/DDD3DAB40E5B1AA2C12571B6006F837A
# ✅ Downloaded: vlada_zaznamy\1999\1999-02-24.doc
# Found link: ../0/965AD0C9517D041BC12571B60070B393
# ✅ Downloaded: vlada_zaznamy\1999\1999-02-17.doc
# Found link: ../0/A9A1B082B1C7D63CC12571B6006EFF00
# ✅ Downloaded: vlada_zaznamy\1999\1999-02-08.doc
# Found link: ../0/2A85324CDBD094D0C12571B6006C115E
# ✅ Downloaded: vlada_zaznamy\1999\1999-02-01.doc
# Found link: ../0/1A6449AB3E54CB78C12571B6006F256C
# ✅ Downloaded: vlada_zaznamy\1999\1999-01-27.doc
# Found link: ../0/DDE77D6D9266E0BBC12571B6006FEB49
# ✅ Downloaded: vlada_zaznamy\1999\1999-01-20.doc
# Found link: ../0/66671C6F74F2C532C12571B600709419
# ✅ Downloaded: vlada_zaznamy\1999\1999-01-11.doc
# Found link: ../0/0CA3D2F610C9242EC12571B6006D65D2
# ✅ Downloaded: vlada_zaznamy\1999\1999-01-06.doc
#
# 📅 Year 2000
# Found 55 meetings
# Found link: ../0/12877259B0D66F56C12571B6006F8CE5
# ✅ Downloaded: vlada_zaznamy\2000\2000-12-18.doc
# Found link: ../0/1B01FD55B4DB753CC12571B6006BB5A2
# ✅ Downloaded: vlada_zaznamy\2000\2000-12-11.doc
# Found link: ../0/D597F5C162A002FEC12571B6006C81C5
# ✅ Downloaded: vlada_zaznamy\2000\2000-12-04.doc
# Found link: ../0/769F99E181BB1B28C12571B6006C16C7
# ✅ Downloaded: vlada_zaznamy\2000\2000-11-28.doc
# Found link: ../0/BDDA85AFC7001E3EC12571B6006E9F0E
# ✅ Downloaded: vlada_zaznamy\2000\2000-11-27.doc
# Found link: ../0/ED62E4E854FD7126C12571B6006D750B
# ✅ Downloaded: vlada_zaznamy\2000\2000-11-22.doc
# ...
# Found link: ../0/3E43488F0B62FD7EC12571B6006BE896
# ✅ Downloaded: vlada_zaznamy\2005\2005-02-23.doc
# Found link: ../0/14C0B8E42204D016C12571B6006EA440
# ✅ Downloaded: vlada_zaznamy\2005\2005-02-16.doc
# Found link: ../0/B51EE6FC35A2ACD3C12571B6006DC161
# ✅ Downloaded: vlada_zaznamy\2005\2005-02-09.doc
# Found link: ../0/6352AA945D854835C12571B6006DCF8E
# ✅ Downloaded: vlada_zaznamy\2005\2005-02-02.doc
# Found link: ../0/0EDB175DD8E77B93C12571B6007079A2
# ✅ Downloaded: vlada_zaznamy\2005\2005-01-26.doc
# Found link: ../0/DDCFC38CBAB4C1A5C12571B6006FB9A7
# ✅ Downloaded: vlada_zaznamy\2005\2005-01-19.doc
# Found link: ../0/AEBB22491C6BA46DC12571B6006B8B2D
# ✅ Downloaded: vlada_zaznamy\2005\2005-01-12.doc
# Found link: ../0/9AE22129DD28835AC12571B6006C9EB2
# ✅ Downloaded: vlada_zaznamy\2005\2005-01-05.doc
# Found link: ../0/14D83B7761DB3279C12571B6006D05F1
# ✅ Downloaded: vlada_zaznamy\2005\2005-01-04.doc
#
# 📅 Year 2006
# Found 56 meetings
# Found link: ../0/4FC1A660E669C1C9C12572480042EC8E
# ✅ Downloaded: vlada_zaznamy\2006\2006-12-20.doc
# Found link: ../0/B531D5C1C0750424C12572490044044D
# ✅ Downloaded: vlada_zaznamy\2006\2006-12-12.doc
# Found link: ../0/3563D2155737F24EC125723600350E75
# ✅ Downloaded: vlada_zaznamy\2006\2006-12-06.doc
# Found link: ../0/AADDADE040BFFC19C125723C004237E3
# ✅ Downloaded: vlada_zaznamy\2006\2006-11-30.doc
# Found link: ../0/1B92FCB5A6CE36B1C1257228002D929A
# ✅ Downloaded: vlada_zaznamy\2006\2006-11-22.doc
# Found link: ../0/F9F52B82309BC96DC125722500290E70
# ✅ Downloaded: vlada_zaznamy\2006\2006-11-15.doc
# Found link: ../0/F80A0ECA6F97565DC1257227005EFF38
# ✅ Downloaded: vlada_zaznamy\2006\2006-11-08.doc
# Found link: ../0/A5EBB51E6D6742F5C1257214002ABCAB
# ✅ Downloaded: vlada_zaznamy\2006\2006-11-01.doc
# Found link: ../0/1452E46E8C365039C125720D002B6E0C
# ✅ Downloaded: vlada_zaznamy\2006\2006-10-25.doc
# Found link: ../0/19B3D0CAA56ED35BC1257205002A943F
# ✅ Downloaded: vlada_zaznamy\2006\2006-10-18.doc
# Found link: ../0/C77F1A315DB1C698C12572020033C679
# ✅ Downloaded: vlada_zaznamy\2006\2006-10-11.doc
# Found link: ../0/2B033F4904961036C12571F800352788
# ✅ Downloaded: vlada_zaznamy\2006\2006-10-04.doc
# Found link: ../0/DD35BC6F6819258FC12571FB002863C3
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-29.doc
# Found link: ../0/850475893AAA9DD6C12571F4002A12BD
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-27.doc
# Found link: ../0/968321B67E477040C12571F000377993
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-25.doc
# Found link: ../0/5BFE82C71E29F343C12571F50026F23A
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-22.doc
# Found link: ../0/2E6431A1DC155F97C12571EA0023E474
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-20.doc
# Found link: ../0/DA0575E9082360DBC12571E700266EA6
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-13.doc
# Found link: ../0/5D1B435DA18231F1C12571E0004B6DEB
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-06.doc
# Found link: ../0/867ECAD72C12E030C12571E00022884F
# ✅ Downloaded: vlada_zaznamy\2006\2006-09-04.doc
# Found link: ../0/75FE2179CEBBEA2FC12571DF006D5C01
# ✅ Downloaded: vlada_zaznamy\2006\2006-08-30.doc
# Found link: ../0/962AF3DC933A41D8C12571D1002DBDFF
# ✅ Downloaded: vlada_zaznamy\2006\2006-08-23.doc
# Found link: ../0/C0D1592E0BF7408EC12571DF006E008B
# ✅ Downloaded: vlada_zaznamy\2006\2006-08-16.doc
# Found link: ../0/FF99151EE3320183C12571CE0047EEEF
# ✅ Downloaded: vlada_zaznamy\2006\2006-08-02.doc
# Found link: ../0/C4CBC79DB3F49051C125721F00627BAF
# ✅ Downloaded: vlada_zaznamy\2006\2006-07-26.doc
# Found link: ../0/F43C07D8BC763713C12571B6006BBEF7
# ✅ Downloaded: vlada_zaznamy\2006\2006-07-19.doc
# Found link: ../0/A004954B44FCE67CC12571B60070FCBE
# ✅ Downloaded: vlada_zaznamy\2006\2006-07-12.doc
# Found link: ../0/84A60D04694C5385C12571B6006DC70A
# ✅ Downloaded: vlada_zaznamy\2006\2006-07-03.doc
# Found link: ../0/0AD53EC025483E56C12571B6006DB80C
# ✅ Downloaded: vlada_zaznamy\2006\2006-06-28.doc
# Found link: ../0/04DB4423D33A7DB0C12571B6006E6364
# ✅ Downloaded: vlada_zaznamy\2006\2006-06-21.doc
# Found link: ../0/64A9F05BC276FE25C12571B6006D4205
# ✅ Downloaded: vlada_zaznamy\2006\2006-06-14.doc
# Found link: ../0/8F872CBB9B37CCC8C12571B6006E4CDA
# ✅ Downloaded: vlada_zaznamy\2006\2006-06-07.doc
# Found link: ../0/AC0980198921FAE2C12571B60070A661
# ✅ Downloaded: vlada_zaznamy\2006\2006-05-31.doc
# Found link: ../0/487B42366C1CED8EC12571B6006D24E8
# ✅ Downloaded: vlada_zaznamy\2006\2006-05-24.doc
# Found link: ../0/39A2D33D37786B1DC12571B600706921
# ✅ Downloaded: vlada_zaznamy\2006\2006-05-17.doc
# Found link: ../0/CE52D7E772D8F46EC12571B6006BE107
# ✅ Downloaded: vlada_zaznamy\2006\2006-05-10.doc
# ❌ No Záznam z jednání found on https://albatros.odok.gov.cz/usneseni/usneseni_webtest.nsf/web/cs?Open&2006&05-03
# Found link: ../0/DA989237EB67C14FC12571B6006DBF6D
# ✅ Downloaded: vlada_zaznamy\2006\2006-04-26.doc
# Found link: ../0/71FA981BB8F349D5C12571B6006C6898
# ✅ Downloaded: vlada_zaznamy\2006\2006-04-19.doc
# Found link: ../0/1F2F243CC771E1EFC12571B60070CCD6
# ✅ Downloaded: vlada_zaznamy\2006\2006-04-12.doc
# Found link: ../0/E8CE15E52CBEC2B5C12571B6006BF0F1
# ✅ Downloaded: vlada_zaznamy\2006\2006-04-05.doc
# Found link: ../0/A82E8CB40E8C9C9EC12571B6006BAB8D
# ✅ Downloaded: vlada_zaznamy\2006\2006-04-02.doc
# Found link: ../0/141C79AF732A151FC12571B6006E22D1
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-30.doc
# Found link: ../0/238564436D64740FC12571B6006D3724
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-29.doc
# Found link: ../0/8403B1DDB8BA23B1C12571B6006D807D
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-22.doc
# Found link: ../0/7A4EA29825DDA4E9C12571B6006EFED6
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-15.doc
# Found link: ../0/BEAF70B02114FB08C12571B6006F31E0
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-08.doc
# Found link: ../0/69EC7906890A4DCDC12571B6006BB9B2
# ✅ Downloaded: vlada_zaznamy\2006\2006-03-01.doc
# Found link: ../0/C892F407BC6BE8F5C12571B6006C0007
# ✅ Downloaded: vlada_zaznamy\2006\2006-02-22.doc
# Found link: ../0/F3648C63AE79D3C3C12571B6007027B0
# ✅ Downloaded: vlada_zaznamy\2006\2006-02-15.doc
# Found link: ../0/2A83A1ADAA50E29FC12571B6006D585A
# ✅ Downloaded: vlada_zaznamy\2006\2006-02-08.doc
# Found link: ../0/8A6A4012895395E9C12571B6006DECEE
# ✅ Downloaded: vlada_zaznamy\2006\2006-02-01.doc
# Found link: ../0/B064BEE4BB950D1CC12571B6006C6D29
# ✅ Downloaded: vlada_zaznamy\2006\2006-01-25.doc
# Found link: ../0/979E053DAB2D8F61C12571B6006C06A6
# ✅ Downloaded: vlada_zaznamy\2006\2006-01-18.doc
# Found link: ../0/A1AF820B61D79003C12571B6006EDCF6
# ✅ Downloaded: vlada_zaznamy\2006\2006-01-11.doc
# Found link: ../0/A420F9FA1D2E40A5C12571B6006C5CCC
# ✅ Downloaded: vlada_zaznamy\2006\2006-01-04.doc
#
# 📅 Year 2007
# Found 50 meetings
# Found link: ../0/94D278BF4B51C172C125756600241797
# ✅ Downloaded: vlada_zaznamy\2007\2007-12-19.doc
# Found link: ../0/DB3FEF2AE4F7F65AC12575660023DAE2
# ✅ Downloaded: vlada_zaznamy\2007\2007-12-12.doc
# Found link: ../0/867B04A64427B3D2C12575660023E647
# ✅ Downloaded: vlada_zaznamy\2007\2007-12-07.doc
# Found link: ../0/67CDD16CC57DA86DC12575680048588F
# ✅ Downloaded: vlada_zaznamy\2007\2007-12-04.doc
# Found link: ../0/E523DAC18408AF56C12575670022B202
# ✅ Downloaded: vlada_zaznamy\2007\2007-11-28.doc
# Found link: ../0/853BC726B492BEBCC12575680022F8D9
# ✅ Downloaded: vlada_zaznamy\2007\2007-11-21.doc
# Found link: ../0/DC40D1992E497F60C125756800227659
# ✅ Downloaded: vlada_zaznamy\2007\2007-11-14.doc
# Found link: ../0/32893D8D433845A4C12575670025A29B
# ✅ Downloaded: vlada_zaznamy\2007\2007-11-07.doc
# Found link: ../0/2157019BA203C700C125756700270CAA
# ✅ Downloaded: vlada_zaznamy\2007\2007-10-29.doc
# Found link: ../0/6F92D8044A0D1195C125756700272CB7
# ✅ Downloaded: vlada_zaznamy\2007\2007-10-22.doc
# Found link: ../0/F5FCF1762C655F99C12575670027361C
# ✅ Downloaded: vlada_zaznamy\2007\2007-10-15.doc
# Found link: ../0/8FE02E8F06EFCAC4C125736A0024EADE
# ✅ Downloaded: vlada_zaznamy\2007\2007-10-10.doc
# Found link: ../0/73990B075CD01015C12573630024D8A4
# ✅ Downloaded: vlada_zaznamy\2007\2007-10-03.doc
# Found link: ../0/2BF7348754FBE56BC125735A00274DDA
# ✅ Downloaded: vlada_zaznamy\2007\2007-09-24.doc
# Found link: ../0/75AA6E5B747E8B1AC125735500250A07
# ✅ Downloaded: vlada_zaznamy\2007\2007-09-19.doc
# Found link: ../0/1B91D71E3454BB3FC125734F00367201
# ✅ Downloaded: vlada_zaznamy\2007\2007-09-12.doc
# Found link: ../0/DD7F35A4EB3430E9C125734700253541
# ✅ Downloaded: vlada_zaznamy\2007\2007-09-05.doc
# Found link: ../0/735F8857CF336E7BC125734400437954
# ✅ Downloaded: vlada_zaznamy\2007\2007-08-29.doc
# Found link: ../0/166AE9911D36FC4AC125733D001FE4BE
# ✅ Downloaded: vlada_zaznamy\2007\2007-08-22.doc
# Found link: ../0/ADCD3C62F69C99C4C12573300021F1B7
# ✅ Downloaded: vlada_zaznamy\2007\2007-08-13.doc
# Found link: ../0/50A6A94D234E46F1C125731D00276DF8
# ✅ Downloaded: vlada_zaznamy\2007\2007-07-25.doc
# Found link: ../0/6A25ADA9461A26F3C125731A0045DCFF
# ✅ Downloaded: vlada_zaznamy\2007\2007-07-18.doc
# Found link: ../0/A542B96FE1C150EEC125730E0041D181
# ✅ Downloaded: vlada_zaznamy\2007\2007-07-11.doc
# Found link: ../0/E91C67C13A2563D4C1257301002BC7B1
# ✅ Downloaded: vlada_zaznamy\2007\2007-06-27.doc
# Found link: ../0/31EF7196A079814BC12572F800401BDE
# ✅ Downloaded: vlada_zaznamy\2007\2007-06-18.doc
# Found link: ../0/4C2D2EF03034EE16C12572F1002C82FD
# ✅ Downloaded: vlada_zaznamy\2007\2007-06-11.doc
# Found link: ../0/E3CBE633C6D6354FC12572EC00202BB2
# ✅ Downloaded: vlada_zaznamy\2007\2007-06-04.doc
# Found link: ../0/BDE860BA7616E8D8C12572E50022F64C
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-30.doc
# Found link: ../0/98C52B3A33531E2AC12572E6002598FC
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-25.doc
# Found link: ../0/8619A37D1367609CC12572DE002735E0
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-23.doc
# Found link: ../0/178DD59616CD0751C12572D70023CA29
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-16.doc
# Found link: ../0/17CB44348716DB79C12572DD003925B5
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-14.doc
# Found link: ../0/A8E521082A29BA2AC12572C900353256
# ✅ Downloaded: vlada_zaznamy\2007\2007-05-02.doc
# Found link: ../0/A5DB7A5AE8636118C12572C20025B0BD
# ✅ Downloaded: vlada_zaznamy\2007\2007-04-25.doc
# Found link: ../0/EC4EAE5A97102D11C12572BB002B2167
# ✅ Downloaded: vlada_zaznamy\2007\2007-04-18.doc
# Found link: ../0/069CB65D27697AB0C12572B900232BCD
# ✅ Downloaded: vlada_zaznamy\2007\2007-04-11.doc
# Found link: ../0/859515B1F5B05361C12572AD003F48DA
# ✅ Downloaded: vlada_zaznamy\2007\2007-04-04.doc
# Found link: ../0/7893917DD3D2785CC12572AC0032F1F9
# ✅ Downloaded: vlada_zaznamy\2007\2007-04-02.doc
# Found link: ../0/4145C7F87610164EC12572A6002B1110
# ✅ Downloaded: vlada_zaznamy\2007\2007-03-28.doc
# Found link: ../0/EC3289472F8287B2C125729D0037408D
# ✅ Downloaded: vlada_zaznamy\2007\2007-03-19.doc
# Found link: ../0/E3C112BD8437F453C1257298002D1386
# ✅ Downloaded: vlada_zaznamy\2007\2007-03-12.doc
# Found link: ../0/E04C7CF79C609A31C1257291002EDE58
# ✅ Downloaded: vlada_zaznamy\2007\2007-03-07.doc
# Found link: ../0/287C84C5BBF47F56C125728B004768D0
# ✅ Downloaded: vlada_zaznamy\2007\2007-02-28.doc
# Found link: ../0/E236F09A34E9BFF8C125728300341A41
# ✅ Downloaded: vlada_zaznamy\2007\2007-02-21.doc
# Found link: ../0/DBA7E79C2714B17CC12572740028DA91
# ✅ Downloaded: vlada_zaznamy\2007\2007-02-05.doc
# Found link: ../0/F3C1144C40E69003C125726C0038E4E3
# ✅ Downloaded: vlada_zaznamy\2007\2007-01-29.doc
# Found link: ../0/ADEFBE3704BD90E1C12572680027BA70
# ✅ Downloaded: vlada_zaznamy\2007\2007-01-24.doc
# Found link: ../0/FE06B3C119B70F41C1257260003FAF5C
# ✅ Downloaded: vlada_zaznamy\2007\2007-01-17.doc
# Found link: ../0/26831BCA7DBF3CBAC125725D003EEB2C
# ✅ Downloaded: vlada_zaznamy\2007\2007-01-09.doc
# Found link: ../0/1A265B98F72D6030C125725300433BF5
# ✅ Downloaded: vlada_zaznamy\2007\2007-01-03.doc
#
# 📅 Year 2008
# Found 47 meetings
# Found link: ../0/57BEA08FACCE846AC125752700451A45
# ✅ Downloaded: vlada_zaznamy\2008\2008-12-19.doc
# Found link: ../0/8A1915567A59091AC1257528004730A3
# ✅ Downloaded: vlada_zaznamy\2008\2008-12-16.doc
# Found link: ../0/6CDF20C8338ADAABC1257B1E004047B8
# ✅ Downloaded: vlada_zaznamy\2008\2008-12-10.doc
# Found link: ../0/31C4730D5ED7BEF2C1257527004DC57C
# ✅ Downloaded: vlada_zaznamy\2008\2008-12-01.doc
# Found link: ../0/7119444AF1B25B58C125750C0049568A
# ✅ Downloaded: vlada_zaznamy\2008\2008-11-27.doc
# Found link: ../0/14D0B78CDC44A592C125755300251D56
# ✅ Downloaded: vlada_zaznamy\2008\2008-11-24.doc
# Found link: ../0/EE6FFBB23D793CECC125750C002415C2
# ✅ Downloaded: vlada_zaznamy\2008\2008-11-19.doc
# Found link: ../0/0882338EE0C5DBC8C12575530027B0FE
# ✅ Downloaded: vlada_zaznamy\2008\2008-11-12.doc
# Found link: ../0/22AE7ADE48C55BF8C1257553002951A5
# ✅ Downloaded: vlada_zaznamy\2008\2008-11-03.doc
# Found link: ../0/12C13DB3F4116A1CC12574E90046D512
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-21.doc
# Found link: ../0/0D2832B89D016C39C12575540022FB9A
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-20.doc
# Found link: ../0/FE2F46EF570503A5C125755400238479
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-15.doc
# Found link: ../0/0BC17AB4CE3D27C2C12574E1003F06CF
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-14.doc
# Found link: ../0/BB17E6D5F55B6682C12575540024141E
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-08.doc
# Found link: ../0/6FACC6162DE8C43EC12574DD004468BF
# ✅ Downloaded: vlada_zaznamy\2008\2008-10-01.doc
# Found link: ../0/278198594645D905C125755500231A4A
# ✅ Downloaded: vlada_zaznamy\2008\2008-09-22.doc
# Found link: ../0/EF14A0532C8B4E11C12575550023DDBF
# ✅ Downloaded: vlada_zaznamy\2008\2008-09-17.doc
# Found link: ../0/002A4868C3320D9AC12574CF006476C9
# ✅ Downloaded: vlada_zaznamy\2008\2008-09-10.doc
# Found link: ../0/A3AA51809D3AD179C12574C00028BC1B
# ✅ Downloaded: vlada_zaznamy\2008\2008-09-03.doc
# Found link: ../0/A532B55F2B695021C1257555002DD9A3
# ✅ Downloaded: vlada_zaznamy\2008\2008-08-27.doc
# Found link: ../0/AE644C2B0A5D4EC7C1257555002FA6EC
# ✅ Downloaded: vlada_zaznamy\2008\2008-08-20.doc
# Found link: ../0/C264BAE43C0A86D2C125748E00450FBE
# ✅ Downloaded: vlada_zaznamy\2008\2008-07-23.doc
# Found link: ../0/2D3D4E0B293F4DFFC125755500310AB6
# ✅ Downloaded: vlada_zaznamy\2008\2008-07-09.doc
# Found link: ../0/0CBB01CBFFB5646CC125756A00620CF7
# ✅ Downloaded: vlada_zaznamy\2008\2008-07-02.doc
# Found link: ../0/1F3EE063C3529B2DC1257482003E6651
# ✅ Downloaded: vlada_zaznamy\2008\2008-06-27.doc
# Found link: ../0/5429624BE31D3123C12575590022B124
# ✅ Downloaded: vlada_zaznamy\2008\2008-06-09.doc
# Found link: ../0/D8D9D0890F62B0E8C1257463004A880A
# ✅ Downloaded: vlada_zaznamy\2008\2008-06-02.doc
# Found link: ../0/98E07B1BA2ADA37FC125746E006F9AB1
# ✅ Downloaded: vlada_zaznamy\2008\2008-05-28.doc
# Found link: ../0/3996AA9DDE0132FFC12574D000203539
# ✅ Downloaded: vlada_zaznamy\2008\2008-05-21.doc
# Found link: ../0/E51C510873FB6582C125756A005E94D6
# ✅ Downloaded: vlada_zaznamy\2008\2008-05-14.doc
# Found link: ../0/94B63AF65DB4EAB4C125756A005D76EA
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-30.doc
# Found link: ../0/A845494EE1CAB177C125755B002070AE
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-28.doc
# Found link: ../0/F3E6E50C23E0AC95C125756A005E96CC
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-21.doc
# Found link: ../0/0D02AE4EDDAC7954C125756A005F66EF
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-16.doc
# Found link: ../0/AD92EBFD674A33F2C125755B0024D724
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-09.doc
# Found link: ../0/BCFBD6FE4FC2C658C125755B00258720
# ✅ Downloaded: vlada_zaznamy\2008\2008-04-02.doc
# Found link: ../0/29F52B1B77CABF4EC125755C0022E5DD
# ✅ Downloaded: vlada_zaznamy\2008\2008-03-26.doc
# Found link: ../0/0C783BB0DCF9F4E0C125755C0023E36B
# ✅ Downloaded: vlada_zaznamy\2008\2008-03-17.doc
# Found link: ../0/3EDF9E555320E414C125756A005FE5CE
# ✅ Downloaded: vlada_zaznamy\2008\2008-03-10.doc
# Found link: ../0/E6D5F922C12DCE74C125755C002504D1
# ✅ Downloaded: vlada_zaznamy\2008\2008-03-05.doc
# Found link: ../0/39909E31305F4009C125756A0061F64C
# ✅ Downloaded: vlada_zaznamy\2008\2008-02-25.doc
# Found link: ../0/61FB876485049C86C12575680048F7B0
# ✅ Downloaded: vlada_zaznamy\2008\2008-02-11.doc
# Found link: ../0/5741EBEC52A69B73C125755C00271830
# ✅ Downloaded: vlada_zaznamy\2008\2008-02-04.doc
# Found link: ../0/69FFD5393CC6CEEEC125755C002830FC
# ✅ Downloaded: vlada_zaznamy\2008\2008-01-30.doc
# Found link: ../0/10C9A2F020CF1DB7C125755C00291B7F
# ✅ Downloaded: vlada_zaznamy\2008\2008-01-23.doc
# Found link: ../0/AA8C92CD26A785E0C12573D10029CA2A
# ✅ Downloaded: vlada_zaznamy\2008\2008-01-16.doc
# Found link: ../0/78318791FB185F6EC125755C002AF070
# ✅ Downloaded: vlada_zaznamy\2008\2008-01-09.doc

# %% [markdown]
# ## Convert format

# %%
import os
import win32com.client

def convert_doc_to_docx(root_dir="vlada_zaznamy"):
    """
    Recursively traverses the given directory and converts all `.doc` files to `.docx` format
    using Microsoft Word via COM automation (Windows only).

    Args:
        root_dir (str): Root directory to scan for `.doc` files (default: "vlada_zaznamy")
    """
    # Launch an instance of Microsoft Word (hidden window)
    word = win32com.client.Dispatch("Word.Application")
    word.Visible = False # Prevent Word UI from showing

    # Recursively walk through the directory tree
    for root, _, files in os.walk(root_dir):
        for file in files:
            # Check for .doc files that are not already .docx
            if file.endswith(".doc") and not file.endswith(".docx"):
                doc_path = os.path.abspath(os.path.join(root, file))
                docx_path = doc_path + "x"  # .docx

                # Only convert if the target .docx doesn't already exist
                if not os.path.exists(docx_path):
                    try:
                        doc = word.Documents.Open(doc_path)
                        # Save as .docx format (16 = wdFormatDocumentDefault)
                        doc.SaveAs(docx_path, FileFormat=16)
                        doc.Close()
                        print(f"✅ Converted: {doc_path} → {docx_path}")
                    except Exception as e:
                        print(f"❌ Failed to convert {doc_path}: {e}")

    word.Quit()

# %% [markdown]
# ## Search for president

# %%
from docx import Document
import os

def extract_context(text, keyword, window=3):
    """
    Extracts contextual snippets around a given keyword in the input text.
    For every occurrence of the keyword, it returns a window of N words before and after.

    Args:
        text (str): The full input text to search through.
        keyword (str): The word to find within the text.
        window (int): Number of words to include before and after the keyword.

    Returns:
        List[str]: A list of string snippets containing the keyword in context.
    """
    words = text.split()
    keyword = keyword.lower()
    results = []

    for i, word in enumerate(words):
        if keyword in word.lower():
            start = max(0, i - window)
            end = min(len(words), i + window + 1)
            snippet = " ".join(words[start:end])
            results.append(snippet)
    return results

def search_word_in_docx(root_dir="vlada_zaznamy", keyword="prezident", output_file="matches.txt"):
    """
    Searches all `.docx` files in the given directory tree for a keyword and extracts surrounding context.

    Args:
        root_dir (str): Root folder to search for `.docx` files.
        keyword (str): Keyword to search for (case-insensitive).
        output_file (str): Output text file where matches will be recorded.
    """
    keyword = keyword.lower()
    num_of_files = 0
    matches = []

    with open(output_file, "w", encoding="utf-8") as f:
        for root, _, files in os.walk(root_dir):
            for file in files:
                if file.endswith(".docx"):
                    num_of_files += 1
                    path = os.path.join(root, file)
                    try:
                        # Open the .docx file using python-docx
                        doc = Document(path)
                        # Extract non-empty paragraphs
                        paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]
                        context_matches = []

                        # Search for keyword in each paragraph
                        for para in paragraphs:
                            if keyword in para.lower():
                                # Extract windowed context around keyword
                                context_matches.extend(extract_context(para, keyword))

                        # If keyword found, save match info to file
                        if context_matches:
                            matches.append(path)
                            match_str = " | ".join(context_matches)
                            f.write(f"{path} : {match_str}\n")
                    except Exception as e:
                        print(f"⚠️ Error reading {path}: {e}")

    print(f"\nTotal documents containing '{keyword}': {len(matches)}")
    print(f"Number of files: {num_of_files}")
    print(f"Percentage: {len(matches) / num_of_files * 100:.2f}%")
    print(f"\n✅ Saved contextual matches to: {output_file}")

    return matches

# convert_doc_to_docx()
search_word_in_docx()
# Out:
# Total documents containing 'nil prezident republiky': 0
# Number of files: 1878
# Percentage: 0.00%
#
# ✅ Saved contextual matches to: matches_nil prezident republiky.txt
# []

# %%
def filter_matches_by_phrase(input_file="matches_prezident.txt", phrase="prezident republiky"):
    """
    Filters lines from a keyword match file that contain a specific phrase (case-insensitive),
    and writes them to a new output file.

    Args:
        input_file (str): File containing raw keyword context matches.
        phrase (str): Specific phrase to search for (e.g., 'prezident republiky').

    Output:
        A new file named 'matches_prezident_republiky.txt' (based on phrase) is created with filtered results.
    """
    # Construct output file name by replacing spaces with underscores
    output_file = f"matches_{phrase.replace(' ', '_')}.txt"
    phrase = phrase.lower()

    with open(input_file, "r", encoding="utf-8") as infile, \
         open(output_file, "w", encoding="utf-8") as outfile:
        
        kept = 0
        for line in infile:
            # If the phrase appears in the line (case-insensitive), write it to the output
            if phrase in line.lower():
                outfile.write(line)
                kept += 1

    print(f"✅ Done. Kept {kept} lines containing '{phrase}'.")
    print(f"📝 Saved to: {output_file}")
    
filter_matches_by_phrase("matches_prezident.txt", "nil prezident republiky")
# Out:
# ✅ Done. Kept 27 lines containing 'nil prezident republiky'.
# 📝 Saved to: matches_nil_prezident_republiky.txt

# %%
import os
from docx import Document

def extract_context(text, focus_keyword, window=3):
    """Extracts context around a specific keyword from a paragraph."""
    words = text.split()
    focus_keyword = focus_keyword.lower()
    results = []

    for i, word in enumerate(words):
        if focus_keyword in word.lower():
            start = max(0, i - window)
            end = min(len(words), i + window + 1)
            snippet = " ".join(words[start:end])
            results.append(snippet)
    return results

def paragraph_contains(text, keywords):
    """Returns True if the paragraph contains all keywords."""
    text_lower = text.lower()
    return any(kw.lower() in text_lower for kw in keywords)


def process_docx_file(path, match_keywords, focus_keyword, window=3):
    """Processes a .docx file. Returns contextual matches and whether it contains all match keywords."""
    try:
        doc = Document(path)
        paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]
        full_text = " ".join(paragraphs)
        file_contains_all = paragraph_contains(full_text, match_keywords)

        context_snippets = []
        if file_contains_all:
            for para in paragraphs:
                if focus_keyword.lower() in para.lower():
                    context_snippets.extend(extract_context(para, focus_keyword, window))

        return file_contains_all, context_snippets
    except Exception as e:
        print(f"⚠️ Error reading {path}: {e}")
        return False, []


def search_keywords_in_docx(
    root_dir="vlada_zaznamy",
    match_keywords=["prezident", "účast"],
    focus_keyword="prezident",
    output_file="matches_structured.txt",
    window=3
):
    """
    Searches all `.docx` files in a directory for occurrences of one or more keywords.
    It extracts context around a specific focus keyword if any of the match keywords are found.

    Args:
        root_dir (str): Path to the root directory containing `.docx` files.
        match_keywords (list): List of keywords to trigger search (e.g., ['prezident', 'účast']).
        focus_keyword (str): The word around which contextual windows are extracted (e.g., 'prezident').
        output_file (str): Path to output text file where matches will be recorded.
        window (int): Number of words before and after the focus keyword to include in each snippet.
    """
    match_keywords = [kw.lower() for kw in match_keywords]
    focus_keyword = focus_keyword.lower()

    matches = []
    num_of_files = 0

    with open(output_file, "w", encoding="utf-8") as f:
        for root, _, files in os.walk(root_dir):
            for file in files:
                if file.endswith(".docx"):
                    num_of_files += 1
                    path = os.path.join(root, file)
                    # Process each document to extract keyword-based snippets
                    contains_any, snippets = process_docx_file(path, match_keywords, focus_keyword, window)
                    # Save if any of the match keywords were found and context around focus_keyword was extracted
                    if contains_any and snippets:
                        matches.append(path)
                        f.write(f"{path} : {' | '.join(snippets)}\n")

    print(f"\nTotal documents containing any of {match_keywords}: {len(matches)}")
    print(f"Number of files scanned: {num_of_files}")
    print(f"Percentage: {len(matches) / num_of_files * 100:.2f}%")
    print(f"✅ Contextual matches (focused on '{focus_keyword}') saved to: {output_file}")

    return matches

# for prezident in ["havel", "klaus", "zeman", "pavel"]:
for prezident in [""]:
    search_keywords_in_docx(
        root_dir="vlada_zaznamy",
        match_keywords=["účasti prezidenta republiky", "účastnil prezident republiky", "vystoupil prezident", "přítomen prezident republiky"],
        focus_keyword="prezident",
        output_file=f"matches_structured_{prezident}.txt"
    )
# Out:
# Total documents containing any of ['účasti prezidenta republiky', 'účastnil prezident republiky', 'vystoupil prezident', 'přítomen prezident republiky']: 50
# Number of files scanned: 1878
# Percentage: 2.66%
# ✅ Contextual matches (focused on 'prezident') saved to: matches_structured_.txt

# %% [markdown]
# ### Basic statistics

# %%
import re
from datetime import datetime
from collections import defaultdict
import matplotlib.pyplot as plt

# --- Define presidential terms ---
presidents = [
    ("Václav Havel", datetime(1993, 2, 2), datetime(2003, 2, 2)),
    ("Václav Klaus", datetime(2003, 3, 7), datetime(2013, 3, 7)),
    ("Miloš Zeman", datetime(2013, 3, 8), datetime(2023, 3, 8)),
    ("Petr Pavel", datetime(2023, 3, 9), datetime.now()),
]

# --- Initialize counters ---
year_counts = defaultdict(int)
month_counts = defaultdict(int)
president_counts = defaultdict(int)

# --- Regex for extracting date ---
date_pattern = re.compile(r"\d{4}-\d{2}-\d{2}")

# --- Read file and collect stats ---
with open("matches_final.txt", "r", encoding="utf-8") as file:
    for line in file:
        match = date_pattern.search(line)
        if match:
            date_str = match.group()
            try:
                date = datetime.strptime(date_str, "%Y-%m-%d")
                year_counts[date.year] += 1
                month_counts[date.month] += 1
                for name, start, end in presidents:
                    if start <= date <= end:
                        president_counts[name] += 1
                        break
            except ValueError:
                continue

# --- Generic plotting function ---
def plot_histogram(labels, values, title, xlabel, ylabel, filename):
    plt.figure(figsize=(10, 6))
    plt.bar(labels, values, color='skyblue')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

# --- 1. Visits per year ---
years, year_vals = zip(*sorted(year_counts.items()))
plot_histogram(years, year_vals,
               "Number of Presidential Visits per Year",
               "Year", "Number of Visits", "visits_per_year.png")

# --- 2. Visits per month (ordered) ---
month_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_vals = [month_counts[i] for i in range(1, 13)]
plot_histogram(month_labels, month_vals,
               "Monthly Distribution of Presidential Visits",
               "Month", "Number of Visits", "visits_per_month.png")

# --- 3. Visits per president ---
pres_names, pres_vals = zip(*president_counts.items())
plot_histogram(pres_names, pres_vals,
               "Number of Meetings Attended by Each President",
               "President", "Number of Visits", "visits_per_president.png")
